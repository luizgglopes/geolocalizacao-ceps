# %% [markdown]
# # Geolocalização de CEPs

# %%
# Bases OSM: https://download.geofabrik.de/south-america/brazil.html
### DOC: https://download.geofabrik.de/osm-data-in-gis-formats-free.pdf
### Extraidas apenas 'roads', 'places' e 'pois'

# Bases IBGE:
### https://www.ibge.gov.br/geociencias/downloads-geociencias.html
### organizacao_do_territorio > analises_do_territorio > divisao_regional > 
### divisao_regional_do_brasil > divisao_regional_do_brasil_em_regioes_geograficas_2017 > shp > 
### RG2017_regioesgeograficas2017_20180911.zip

### https://www.ibge.gov.br/geociencias/downloads-geociencias.html
### estrutura_territorial > localidades > Shapefile_SHP >
### BR_Localidades_2010_v1.dbf
### BR_Localidades_2010_v1.prj
### BR_Localidades_2010_v1.shp
### BR_Localidades_2010_v1.shx

### ftp://ftp.ibge.gov.br/Censos/Censo_Demografico_2010/Cadastro_Nacional_de_Enderecos_Fins_Estatisticos
### Cadastro Nacional de Enderecos Fins Estatisticos - um por estado - extraidos e renomeados conforme nome do estado
### DOC: https://biblioteca.ibge.gov.br/index.php/biblioteca-catalogo?view=detalhes&id=2101639

# %% [markdown]
# ### Definição de variáveis globais e funções

# %%
# Import das bibliotecas:
import csv, os, re
from collections import OrderedDict
import xml.etree.ElementTree as ET
import fiona
import unicodedata
import datetime
import pandas as pd

# %%
# Retorna a data hora atual:
def get_hora_atual():
    return str(datetime.datetime.now())[:19]

# %%
# Percorre shapefile e imprime a linha solicitada:
def print_linha_shapeFile(arquivo_origem, numero_linha):
    origem = fiona.open(arquivo_origem)
    limite = len(origem)
    if (numero_linha > 0 and numero_linha < limite):
        linha_atual = 0
        for linha in origem:
            if (linha_atual == numero_linha):
                return linha
            if (linha_atual >= limite):
                print('Linha inexistente. Informe um valor menor e superior a zero.')
                break
            linha_atual += 1
    else:
        print('Linha inexistente. Informe um valor menor e superior a zero.')
    origem.close()

# %%
# Extrai variaveis do shapefile, a partir do dicionario informado:
def extrai_variaveis_shapeFile(arquivo_origem, arquivo_destino, numero_linhas, dicionario_variaveis, encoding='ascii'):
    # MODELO DE DICIONARIO:
    # Os campos devem ficar na chave, separados por virgula
    # O valor deve ser um booleano que indica se o campo eh nullable
    #     dicionario_variaveis_shape = {
    #         "properties.name": False, 
    #         "geometry.coordinates": False,
    #         "properties.fclass": True,
    #         "properties.ref": True
    #     }
    lista_campos = list(dicionario_variaveis.keys())
    campos = '|'.join(lista_campos) + '\n'
    origem = fiona.open(arquivo_origem)
    destino = open(arquivo_destino, 'w+', newline='', encoding="utf-8") 
    destino.write(campos)
    if (numero_linhas == -1):
        limite = len(origem)
    else:
        limite = numero_linhas
    print("Total de linhas a serem lidas do arquivo {0}: {1}.\nExtração iniciada às {2}."\
          .format(arquivo_origem, limite, get_hora_atual()))
    linha_atual = 0
    total_linhas = 0
    linha_destino_anterior = []
    for linha in origem:
        linha_destino = []
        valor_principal_nulo = False
        for k, v in dicionario_variaveis.items():
            valor = ''
            aux_k = linha
            k_encontrado = False
            for k1 in k.split('.'):
                if k1 in aux_k.keys():
                    aux_k = aux_k[k1]
                    k_encontrado = True
                else:
                    k_encontrado = False
                    break
            if (k_encontrado and str(aux_k) != 'None'):
                if (encoding != 'ascii'):
                    aux_k = str(aux_k).encode(encoding).decode('utf-8')
                valor = re.sub(r'\|', '', unicodedata.normalize('NFKD', str(aux_k)))\
                    .encode('ascii', 'ignore').decode('utf-8').upper().strip()
            if (v == False and valor == ''):
                valor_principal_nulo = True
                break
            linha_destino.append(valor)
        if (valor_principal_nulo == False):
            if (linha_destino_anterior != linha_destino):
                destino.write('|'.join(linha_destino) + '\n')
                total_linhas +=1
            linha_destino_anterior = linha_destino
        if (linha_atual % 100 == 0):
            progresso = int(100*linha_atual/limite)
            print('Percentual de registros gravados no CSV destino: %d%%\r'%progresso, end="")
        if (linha_atual >= limite):
            break
        linha_atual += 1
    print("Total de linhas gravadas em {0}: {1}.\n Fim da extração às {2}"\
          .format(arquivo_destino, total_linhas, get_hora_atual()))
    origem.close()
    destino.close()

# %%
# Extrai variaves a partir de um arquivo posicional, conforme dicionario de variaveis informado:
def extrai_variaveis_arquivo_posicional(arquivo_origem, arquivo_destino, numero_linhas, dicionario_variaveis):
    lista_campos = list(dicionario_variaveis.keys())
    campos = '|'.join(lista_campos) + '\n'
    origem = open(arquivo_origem, 'r')
    destino = open(arquivo_destino, 'w+', newline='', encoding="utf-8") 
    destino.write(campos)
    if (numero_linhas == -1):
        aux_origem = open(arquivo_origem, 'r')
        limite = sum(1 for l in aux_origem)
        aux_origem.close()
    else:
        limite = numero_linhas
    print("Total de linhas a serem lidas do arquivo {0}: {1}.\nExtração iniciada às {2}."\
          .format(arquivo_origem, limite, get_hora_atual()))
    linha_atual = 0
    total_linhas = 0
    linha_destino_anterior = []
    for linha in origem:
        linha_destino = []
        for k, v in dicionario_variaveis.items():
            valor = re.sub(r'\|', '', unicodedata.normalize('NFKD', linha[v[0]:v[1]]))\
                .encode('ascii', 'ignore').decode('utf-8').upper().strip()
            linha_destino.append(valor)
        if (linha_destino_anterior != linha_destino):
            destino.write('|'.join(linha_destino) + '\n')
            total_linhas +=1
        linha_destino_anterior = linha_destino
        if (linha_atual % 100 == 0):
            progresso = int(100*linha_atual/limite)
            print('Percentual de registros gravados no CSV destino: %d%%\r'%progresso, end="")
        if (linha_atual >= limite):
            break
        linha_atual += 1
    print("Total de linhas gravadas em {0}: {1}.\n Fim da extração às {2}"\
          .format(arquivo_destino, total_linhas, get_hora_atual()))
    origem.close()
    destino.close()

# %%
# Dataframe com codigo da UF segundo IBGE, sigla da UF e regiao:
df_ufs = pd.DataFrame([
    [11, 'RO', 'norte'],
    [12, 'AC', 'norte'],
    [13, 'AM', 'norte'],
    [14, 'RR', 'norte'],
    [15, 'PA', 'norte'],
    [16, 'AP', 'norte'],
    [17, 'TO', 'norte'],
    [21, 'MA', 'nordeste'],
    [22, 'PI', 'nordeste'],
    [23, 'CE', 'nordeste'],
    [24, 'RN', 'nordeste'],
    [25, 'PB', 'nordeste'],
    [26, 'PE', 'nordeste'],
    [27, 'AL', 'nordeste'],
    [28, 'SE', 'nordeste'],
    [29, 'BA', 'nordeste'],
    [31, 'MG', 'sudeste'],
    [32, 'ES', 'sudeste'],
    [33, 'RJ', 'sudeste'],
    [35, 'SP', 'sudeste'],
    [41, 'PR', 'sul'],
    [42, 'SC', 'sul'],
    [43, 'RS', 'sul'],
    [50, 'MS', 'centro-oeste'],
    [51, 'MT', 'centro-oeste'],
    [52, 'GO', 'centro-oeste'],
    [53, 'DF', 'centro-oeste']
], columns=['codigo', 'sigla', 'regiao'])

# %% [markdown]
# ---
#
# ### Estudo e extração dos arquivos

# %% [markdown]
# #### 1. OpenStreetMap (© contribuidores do OpenStreetMap - dados disponíveis sob a Open Database License (ODbL))
#
# Extração de locais e logradouros.

# %%
# Exemplo de linha extraida de ShapeFile Roads da Regiao Centro-Oeste, arquivo do OSM:
print_linha_shapeFile('data/shapefiles/centro-oeste/gis_osm_roads_free_1.shp', 5)
# Out:
# {'type': 'Feature',
#  'id': '5',
#  'geometry': {'type': 'LineString',
#   'coordinates': [(-47.9272013, -15.8452793),
#    (-47.9277525, -15.8451682),
#    (-47.9280343, -15.8450709),
#    (-47.9282637, -15.8449333),
#    (-47.929314, -15.8440503),
#    (-47.9307061, -15.8431258),
#    (-47.9308938, -15.8429529),
#    (-47.9309917, -15.8428136),
#    (-47.931158, -15.8424601),
#    (-47.9312171, -15.8422498)]},
#  'properties': OrderedDict([('osm_id', '10064602'),
#               ('code', 5132),
#               ('fclass', 'trunk_link'),
#               ('name', None),
#               ('ref', None),
#               ('oneway', 'F'),
#               ('maxspeed', 0),
#               ('layer', 0),
#               ('bridge', 'F'),
#               ('tunnel', 'F')])}

# %%
# Lista regioes e tipos de shapefile:
regioes = ['centro-oeste', 'nordeste', 'norte', 'sudeste', 'sul']
tipos_shape = ['roads', 'places', 'pois']

# Define dicionario para aplicacao na funcao:
# O booleano indica se eh nullable:
dicionario_variaveis_shape = {
    "properties.name": False, 
    "geometry.coordinates": False,
    "properties.fclass": True,
    "properties.ref": True
}

# Trata arquivo em loop por todas as regioes e tipos de shapefile:
numero_linhas = -1
for regiao in regioes:
    for tipo_shape in tipos_shape:
        arquivo_origem = "data/shapefiles/{0}/gis_osm_{1}_free_1.shp".format(regiao, tipo_shape)
        arquivo_destino = "data/shapefiles/tratados/{0}_{1}.csv".format(regiao, tipo_shape)
        print("\nExtraindo arquivo do tipo {0} da região '{1}'...".format(tipo_shape, regiao))
        extrai_variaveis_shapeFile(arquivo_origem, arquivo_destino, numero_linhas, dicionario_variaveis_shape)

print("\nFim das extrações.")
# Out:
# Extraindo arquivo do tipo roads da região 'centro-oeste'...
# Total de linhas a serem lidas do arquivo C:/Users/Luiz/Documents/Python/geo/data/shapefiles/centro-oeste/gis_osm_roads_free_1.shp: 430315.
# Extração iniciada às 2020-07-16 12:26:10.
# Total de linhas gravadas em C:/Users/Luiz/Documents/Python/geo/data/shapefiles/tratados/centro-oeste_roads.csv: 179506.
#  Fim da extração às 2020-07-16 12:26:35
#
# Extraindo arquivo do tipo places da região 'centro-oeste'...
# Total de linhas a serem lidas do arquivo C:/Users/Luiz/Documents/Python/geo/data/shapefiles/centro-oeste/gis_osm_places_free_1.shp: 6452.
# Extração iniciada às 2020-07-16 12:26:35.
# Total de linhas gravadas em C:/Users/Luiz/Documents/Python/geo/data/shapefiles/tratados/centro-oeste_places.csv: 6203.
#  Fim da extração às 2020-07-16 12:26:36
#
# Extraindo arquivo do tipo pois da região 'centro-oeste'...
# Total de linhas a serem lidas do arquivo C:/Users/Luiz/Documents/Python/geo/data/shapefiles/centro-oeste/gis_osm_pois_free_1.shp: 17243.
# Extração iniciada às 2020-07-16 12:26:36.
# Total de linhas gravadas em C:/Users/Luiz/Documents/Python/geo/data/shapefiles/tratados/centro-oeste_pois.csv: 11775.
#  Fim da extração às 2020-07-16 12:26:36
#
# Extraindo arquivo do tipo roads da região 'nordeste'...
# Total de linhas a serem lidas do arquivo C:/Users/Luiz/Documents/Python/geo/data/shapefiles/nordeste/gis_osm_roads_free_1.shp: 1374254.
# Extração iniciada às 2020-07-16 12:26:37.
# Total de linhas gravadas em C:/Users/Luiz/Documents/Python/geo/data/shapefiles/tratados/nordeste_roads.csv: 406995.
#  Fim da extração às 2020-07-16 12:27:59
#
# Extraindo arquivo do tipo places da região 'nordeste'...
# Total de linhas a serem lidas do arquivo C:/Users/Luiz/Documents/Python/geo/data/shapefiles/nordeste/gis_osm_places_free_1.shp: 28926.
# Extração iniciada às 2020-07-16 12:27:59.
# Total de linhas gravadas em C:/Users/Luiz/Documents/Python/geo/data/shapefiles/tratados/nordeste_places.csv: 28491.
#  Fim da extração às 2020-07-16 12:28:01
#
# Extraindo arquivo do tipo pois da região 'nordeste'...
# Total de linhas a serem lidas do arquivo C:/Users/Luiz/Documents/Python/geo/data/shapefiles/nordeste/gis_osm_pois_free_1.shp: 48687.
# Extração iniciada às 2020-07-16 12:28:02.
# Total de linhas gravadas em C:/Users/Luiz/Documents/Python/geo/data/shapefiles/tratados/nordeste_pois.csv: 31738.
#  Fim da extração às 2020-07-16 12:28:04
#
# Extraindo arquivo do tipo roads da região 'norte'...
# Total de linhas a serem lidas do arquivo C:/Users/Luiz/Documents/Python/geo/data/shapefiles/norte/gis_osm_roads_free_1.shp: 320894.
# Extração iniciada às 2020-07-16 12:28:04.
# Total de linhas gravadas em C:/Users/Luiz/Documents/Python/geo/data/shapefiles/tratados/norte_roads.csv: 121263.
#  Fim da extração às 2020-07-16 12:28:26
#
# Extraindo arquivo do tipo places da região 'norte'...
# Total de linhas a serem lidas do arquivo C:/Users/Luiz/Documents/Python/geo/data/shapefiles/norte/gis_osm_places_free_1.shp: 16244.
# Extração iniciada às 2020-07-16 12:28:26.
# Total de linhas gravadas em C:/Users/Luiz/Documents/Python/geo/data/shapefiles/tratados/norte_places.csv: 15721.
#  Fim da extração às 2020-07-16 12:28:27
#
# Extraindo arquivo do tipo pois da região 'norte'...
# Total de linhas a serem lidas do arquivo C:/Users/Luiz/Documents/Python/geo/data/shapefiles/norte/gis_osm_pois_free_1.shp: 12002.
# Extração iniciada às 2020-07-16 12:28:27.
# Total de linhas gravadas em C:/Users/Luiz/Documents/Python/geo/data/shapefiles/tratados/norte_pois.csv: 7458.
#  Fim da extração às 2020-07-16 12:28:28
#
# Extraindo arquivo do tipo roads da região 'sudeste'...
# Total de linhas a serem lidas do arquivo C:/Users/Luiz/Documents/Python/geo/data/shapefiles/sudeste/gis_osm_roads_free_1.shp: 1862192.
# Extração iniciada às 2020-07-16 12:28:28.
# Total de linhas gravadas em C:/Users/Luiz/Documents/Python/geo/data/shapefiles/tratados/sudeste_roads.csv: 909933.
#  Fim da extração às 2020-07-16 12:31:08
#
# Extraindo arquivo do tipo places da região 'sudeste'...
# Total de linhas a serem lidas do arquivo C:/Users/Luiz/Documents/Python/geo/data/shapefiles/sudeste/gis_osm_places_free_1.shp: 36288.
# Extração iniciada às 2020-07-16 12:31:09.
# Total de linhas gravadas em C:/Users/Luiz/Documents/Python/geo/data/shapefiles/tratados/sudeste_places.csv: 36121.
#  Fim da extração às 2020-07-16 12:31:11
#
# Extraindo arquivo do tipo pois da região 'sudeste'...
# Total de linhas a serem lidas do arquivo C:/Users/Luiz/Documents/Python/geo/data/shapefiles/sudeste/gis_osm_pois_free_1.shp: 79883.
# Extração iniciada às 2020-07-16 12:31:11.
# Total de linhas gravadas em C:/Users/Luiz/Documents/Python/geo/data/shapefiles/tratados/sudeste_pois.csv: 50892.
#  Fim da extração às 2020-07-16 12:31:15
#
# Extraindo arquivo do tipo roads da região 'sul'...
# Total de linhas a serem lidas do arquivo C:/Users/Luiz/Documents/Python/geo/data/shapefiles/sul/gis_osm_roads_free_1.shp: 877538.
# Extração iniciada às 2020-07-16 12:31:15.
# Total de linhas gravadas em C:/Users/Luiz/Documents/Python/geo/data/shapefiles/tratados/sul_roads.csv: 378400.
#  Fim da extração às 2020-07-16 12:32:17
#
# Extraindo arquivo do tipo places da região 'sul'...
# Total de linhas a serem lidas do arquivo C:/Users/Luiz/Documents/Python/geo/data/shapefiles/sul/gis_osm_places_free_1.shp: 18122.
# Extração iniciada às 2020-07-16 12:32:17.
# Total de linhas gravadas em C:/Users/Luiz/Documents/Python/geo/data/shapefiles/tratados/sul_places.csv: 18060.
#  Fim da extração às 2020-07-16 12:32:18
#
# Extraindo arquivo do tipo pois da região 'sul'...
# Total de linhas a serem lidas do arquivo C:/Users/Luiz/Documents/Python/geo/data/shapefiles/sul/gis_osm_pois_free_1.shp: 53223.
# Extração iniciada às 2020-07-16 12:32:18.
# Total de linhas gravadas em C:/Users/Luiz/Documents/Python/geo/data/shapefiles/tratados
#     (-48.70879566799994, -15.390035668999928, 0.0),
#     (-48.70977115599993, -15.39014971499995, 0.0),
#     (-48.71080121199998, -15.389875169999982, 0.0),
#     (-48.711808592999944, -15.389944040999978, 0.0),
#     (-48.71244195699995, -15.390653253999972, 0.0),
#     (-48.71163851099993, -15.39441597299998, 0.0),
#     (-48.711634678999985, -15.399128649999966, 0.0),
#     (-48.71204718499996, -15.401089618999947, 0.0),
#     (-48.71268957399997, -15.401958428999933, 0.0),
#     (-48.71386178299997, -15.40453527099993, 0.0),
#     (-48.71466413799993, -15.40744011199996, 0.0),
#     (-48.716000178999934, -15.414585965999947, 0.0),
#     (-48.71707778299998, -15.418397758999959, 0.0),
#     (-48.71763241999997, -15.419311318999974, 0.0),
#     (-48.717830866999975, -15.42071077299994, 0.0),
#     (-48.718968925999945, -15.424969717999943, 0.0),
#     (-48.71921847599998, -15.426706242999956, 0.0),
#     (-48.71974693899995, -15.427844291999975, 0.0),
#     (-48.720023277999985, -15.429112332999978, 0.0),
#     (-48.72139295399995, -15.43133101199993, 0.0),
#     (-48.72321909799996, -15.433521783999936, 0.0),
#     (-48.72446820899995, -15.436013137999964, 0.0),
#     (-48.724911203999966, -15.438061301999937, 0.0),
#     (-48.72565911799995, -15.445362598999964, 0.0),
#     (-48.726636259999964, -15.44880468499997, 0.0),
#     (-48.727579713999944, -15.450083136999979, 0.0),
#     (-48.72855755799998, -15.450814037999976, 0.0),
#     (-48.73024702599997, -15.452630605999957, 0.0),
#     (-48.731362238999964, -15.454304810999929, 0.0),
#     (-48.73182947999993, -15.456060021999974, 0.0),
#     (-48.73183193199998, -15.458096871999942, 0.0),
#     (-48.731245282999964, -15.460317865999968, 0.0),
#     ...]]},
#  'properties': OrderedDict([('OBJECTID', 2),
#               ('NOME', 'Vila PropÃ\xadcio'),
#               ('CD_GEOCODI', '5222302'),
#               ('UF', '52'),
#               ('rgi', '520018'),
#               ('nome_rgi', 'Ceres - Rialma - GoianÃ©sia'),
#               ('rgint', '5205'),
#               ('nome_rgint', 'Porangatu - UruaÃ§u')])}

# %%
# Define dicionario para aplicacao na funcao:
dicionario_variaveis_shape = {
    "properties.NOME": False, 
    "properties.CD_GEOCODI": False, 
    "properties.UF": False, 
    "geometry.coordinates": False
}
numero_linhas = -1
arquivo_origem = "data/shapefiles/brasil/divisao_urbano_regional/RG2017_regioesgeograficas2017.shp"
arquivo_destino = "data/shapefiles/tratados/areas_municipios.csv"
print("\nExtraindo arquivo do tipo {0} da região '{1}'...".format(tipo_shape, regiao))
extrai_variaveis_shapeFile(arquivo_origem, arquivo_destino, numero_linhas, dicionario_variaveis_shape, 'latin1')

print("\nFim das extrações.")
# Aproximadamente 30 minutos para todas as tabelas
# Out:
# Extraindo arquivo do tipo pois da região 'sul'...
# Total de linhas a serem lidas do arquivo C:/Users/Luiz/Documents/Python/geo/data/shapefiles/brasil/divisao_urbano_regional/RG2017_regioesgeograficas2017.shp: 5570.
# Extração iniciada às 2020-07-16 14:13:26.
# Total de linhas gravadas em C:/Users/Luiz/Documents/Python/geo/data/shapefiles/tratados/areas_municipios.csv: 5570.
#  Fim da extração às 2020-07-16 14:14:14
#
# Fim das extrações.

# %% [markdown]
# #### 3. Censo 2010

# %%
# Define dicionario para aplicacao na funcao:
dicionario_variaveis_cnefe = {
    "codigo_completo_setor": [0, 14],
    "nome_logradouro": [66, 125],
    "cep": [550, 558]
}
# Lista UFs:
ufs = [ 'AC','AL','AM','AP','BA',
        'CE','DF','ES','GO','MA',
        'MG','MS','MT','PA','PB',
        'PE','PI','PR','RJ','RN',
        'RO','RR','RS','SC','SE',
        'SP','TO']

# Trata arquivo em loop por todas as UFs:
numero_linhas = -1
for uf in ufs:
    arquivo_origem = "data/censo2010/enderecos_fins_estatisticos/{0}.txt".format(uf)
    arquivo_destino = "data/censo2010/enderecos_fins_estatisticos/tratados/{0}.csv".format(uf)
    print("Extraindo arquivo da UF '{0}'...".format(uf))
    extrai_variaveis_arquivo_posicional(arquivo_origem, arquivo_destino, numero_linhas, dicionario_variaveis_cnefe)

print("Fim das extrações.")
# Out:
# Extraindo arquivo da UF 'AC'...
# Total de linhas a serem lidas do arquivo C:/Users/Luiz/Documents/Python/geo/data/censo2010/enderecos_fins_estatisticos/AC.txt: 283321.
# Extração iniciada.
# Total de linhas gravadas em C:/Users/Luiz/Documents/Python/geo/data/censo2010/enderecos_fins_estatisticos/tratados/AC.csv: 15186.
#
# Extraindo arquivo da UF 'AL'...
# Total de linhas a serem lidas do arquivo C:/Users/Luiz/Documents/Python/geo/data/censo2010/enderecos_fins_estatisticos/AL.txt: 1208310.
# Extração iniciada.
# Total de linhas gravadas em C:/Users/Luiz/Documents/Python/geo/data/censo2010/enderecos_fins_estatisticos/tratados/AL.csv: 56267.
#
# Extraindo arquivo da UF 'AM'...
# Total de linhas a serem lidas do arquivo C:/Users/Luiz/Documents/Python/geo/data/censo2010/enderecos_fins_estatisticos/AM.txt: 1091726.
# Extração iniciada.
# Total de linhas gravadas em C:/Users/Luiz/Documents/Python/geo/data/censo2010/enderecos_fins_estatisticos/tratados/AM.csv: 63657.
#
# Extraindo arquivo da UF 'AP'...
# Total de linhas a serem lidas do arquivo C:/Users/Luiz/Documents/Python/geo/data/censo2010/enderecos_fins_estatisticos/AP.txt: 217529.
# Extração iniciada.
# Total de linhas gravadas em C:/Users/Luiz/Documents/Python/geo/data/censo2010/enderecos_fins_estatisticos/tratados/AP.csv: 11791.
#
# Extraindo arquivo da UF 'BA'...
# Total de linhas a serem lidas do arquivo C:/Users/Luiz/Documents/Python/geo/data/censo2010/enderecos_fins_estatisticos/BA.txt: 6474545.
# Extração iniciada.
# Total de linhas gravadas em C:/Users/Luiz/Documents/Python/geo/data/censo2010/enderecos_fins_estatisticos/tratados/BA.csv: 355195.
#
# Extraindo arquivo da UF 'CE'...
# Total de linhas a serem lidas do arquivo C:/Users/Luiz/Documents/Python/geo/data/censo2010/enderecos_fins_estatisticos/CE.txt: 3348627.
# Extração iniciada.
# Total de linhas gravadas em C:/Users/Luiz/Documents/Python/geo/data/censo2010/enderecos_fins_estatisticos/tratados/CE.csv: 152275.
#
# Extraindo arquivo da UF 'DF'...
# Total de linhas a serem lidas do arquivo C:/Users/Luiz/Documents/Python/geo/data/censo2010/enderecos_fins_estatisticos/DF.txt: 956344.
# Extração iniciada.
# Total de linhas gravadas em C:/Users/Luiz/Documents/Python/geo/data/censo2010/enderecos_fins_estatisticos/tratados/DF.csv: 32939.
#
# Extraindo arquivo da UF 'ES'...
# Total de linhas a serem lidas do arquivo C:/Users/Luiz/Documents/Python/geo/data/censo2010/enderecos_fins_estatisticos/ES.txt: 1657966.
# Extração iniciada.
# Total de linhas gravadas em C:/Users/Luiz/Documents/Python/geo/data/censo2010/enderecos_fins_estatisticos/tratados/ES.csv: 92285.
#
# Extraindo arquivo da UF 'GO'...
# Total de linhas a serem lidas do arquivo C:/Users/Luiz/Documents/Python/geo/data/censo2010/enderecos_fins_estatisticos/GO.txt: 2733412.
# Extração iniciada.
# Total de linhas gravadas em C:/Users/Luiz/Documents/Python/geo/data/censo2010/enderecos_fins_estatisticos/tratados/GO.csv: 180877.
#
# Extraindo arquivo da UF 'MA'...
# Total de linhas a serem lidas do arquivo C:/Users/Luiz/Documents/Python/geo/data/censo2010/enderecos_fins_estatisticos/MA.txt: 2290312.
# Extração iniciada.
# Total de linhas gravadas em C:/Users/Luiz/Documents/Python/geo/data/censo2010/enderecos_fins_estatisticos/tratados/MA.csv: 120328.
#
# Extraindo arquivo da UF 'MG'...
# Total de linhas a serem lidas do arquivo C:/Users/Luiz/Documents/Python/geo/data/censo2010/enderecos_fins_estatisticos/MG.txt: 8922565.
# Extração iniciada.
# Total de linhas gravadas em C:/Users/Luiz/Documents/Python/geo/data/censo2010/enderecos_fins_estatisticos/tratados/MG.csv: 543695.
#
# Extraindo arquivo da UF 'MS'...
# Total de linhas a serem lidas do arquivo C:/Users/Luiz/Documents/Python/geo/data/censo2010/enderecos_fins_estatisticos/MS.txt: 1101543.
# Extração iniciada.
# Total de linhas gravadas em C:/Users/Luiz/Documents/Python/geo/data/censo2010/enderecos_fins_estatisticos/tratados/MS.csv: 68423.
#
# Extraindo arquivo da UF 'MT'...
# Total de linhas a serem lidas do arquivo C:/Users/Luiz/Documents/Python/geo/data/censo2010/enderecos_fins_estatisticos/MT.txt: 1376728.
# Extração iniciada.
# Total de linhas gravadas em C:/Users/Luiz/Documents/Python/geo/data/censo2010/enderecos_fins_estatisticos/tratados/MT.csv: 91889.
#
# Extraindo arquivo da UF 'PA'...
# Total de linhas a serem lidas do arquivo C:/Users/Luiz/Documents/Python/geo/data/censo2010/enderecos_fins_estatisticos/PA.txt: 2676742.
# Extração iniciada.
# Total de linhas gravadas em C:/Users/Luiz/Documents/Python/geo/data/censo2010/enderecos_fins_estatisticos/tratados/PA.csv: 128540.
#
# Extraindo arquivo da UF 'PB'...
# Total de linhas a serem lidas do arquivo C:/Users/Luiz/Documents/Python/geo/data/censo2010/enderecos_fins_estatisticos/PB.txt: 1644703.
# Extração iniciada.
# Total de linhas gravadas em C:/Users/Luiz/Documents/Python/geo/data/censo2010/enderecos_fins_estatisticos/tratados/PB.csv: 80494.
#
# Extraindo arquivo da UF 'PE'...
# Total de linhas a serem lidas do arquivo C:/Users/Luiz/Documents/Python/geo/data/censo2010/enderecos_fins_estatisticos/PE.txt: 3624665.
# Extração iniciada.
# Total de linhas gravadas em C:/Users/Luiz/Documents/Python/geo/data/censo2010/enderecos_fins_estatisticos/tratados/PE.csv: 180144.
#
# Extraindo arquivo da UF 'PI'...
# Total de linhas a serem lidas do arquivo C:/Users/Luiz/Documents/Python/geo/data/censo2010/enderecos_fins_estatisticos/PI.txt: 1323611.
# Extração iniciada.
# Total de linhas gravadas em C:/Users/Luiz/Documents/Python/geo/data/censo2010/enderecos_fins_estatisticos/tratados/PI.csv: 82672.
#
# Extraindo arquivo da UF 'PR'...
# Total de linhas a serem lidas do arquivo C:/Users/Luiz/Documents/Python/geo/data/censo2010/enderecos_fins_estatisticos/PR.txt: 4572947.
# Extração iniciada.
# Total de linhas gravadas em C:/Users/Luiz/Documents/Python/geo/data/censo2010/enderecos_fins_estatisticos/tratados/PR.csv: 259411.
#
# Extraindo arquivo da UF 'RJ'...
# Total de linhas a serem lidas do arquivo C:/Users/Luiz/Documents/Python/geo/data/censo2010/enderecos_fins_estatisticos/RJ.txt: 7027708.
# Extração iniciada.
# Total de linhas gravadas em C:/Users/Luiz/Documents/Python/geo/data/censo2010/enderecos_fins_estatisticos/tratados/RJ.csv: 283510.
#
# Extraindo arquivo da UF 'RN'...
# Total de linhas a serem lidas do arquivo C:/Users/Luiz/Documents/Python/geo/data/censo2010/enderecos_fins_estatisticos/RN.txt: 1323224.
# Extração iniciada.
# Total de linhas gravadas em C:/Users/Luiz/Documents/Python/geo/data/censo2010/enderecos_fins_estatisticos/tratados/RN.csv: 72208.
#
# Extraindo arquivo da UF 'RO'...
# Total de linhas a serem lidas do arquivo C:/Users/Luiz/Documents/Python/geo/data/censo2010/enderecos_fins_estatisticos/RO.txt: 698008.
# Extração iniciada.
# Total de linhas gravadas em C:/Users/Luiz/Documents/Python/geo/data/censo2010/enderecos_fins_estatisticos/tratados/RO.csv: 39891.
#
# Extraindo arquivo da UF 'RR'...
# Total de linhas a serem lidas do arquivo C:/Users/Luiz/Documents/Python/geo/data/censo2010/enderecos_fins_estatisticos/RR.txt: 169923.
# Extração iniciada.
# Total de linhas gravadas em C:/Users/Luiz/Documents/Python/geo/data/censo2010/enderecos_fins_estatisticos/tratados/RR.csv: 11314.
#
# Extraindo arquivo da UF 'RS'...
# Total de linhas a serem lidas do arquivo C:/Users/Luiz/Documents/Python/geo/data/censo2010/enderecos_fins_estatisticos/RS.txt: 5129203.
# Extração iniciada.
# Total de linhas gravadas em C:/Users/Luiz/Documents/Python/geo/data/censo2010/enderecos_fins_estatisticos/tratados/RS.csv: 255120.
#
# Extraindo arquivo da UF 'SC'...
# Total de linhas a serem lidas do arquivo C:/Users/Luiz/Documents/Python/geo/data/censo2010/enderecos_fins_estatisticos/SC.txt: 2942785.
# Extração iniciada.
# Total de linhas gravadas em C:/Users/Luiz/Documents/Python/geo/data/censo2010/enderecos_fins_estatisticos/tratados/SC.csv: 154974.
#
# Extraindo arquivo da UF 'SE'...
# Total de linhas a serem lidas do arquivo C:/Users/Luiz/Documents/Python/geo/data/censo2010/enderecos_fins_estatisticos/SE.txt: 879262.
# Extração iniciada.
# Total de linhas gravadas em C:/Users/Luiz/Documents/Python/geo/data/censo2010/enderecos_fins_estatisticos/tratados/SE.csv: 41444.
#
# Extraindo arquivo da UF 'SP'...
# Total de linhas a serem lidas do arquivo C:/Users/Luiz/Documents/Python/geo/data/censo2010/enderecos_fins_estatisticos/SP.txt: 17283155.
# Extração iniciada.
# Total de linhas gravadas em C:/Users/Luiz/Documents/Python/geo/data/censo2010/enderecos_fins_estatisticos/tratados/SP.csv: 918431.
#
# Extraindo arquivo da UF 'TO'...
# Total de linhas a serem lidas do arquivo C:/Users/Luiz/Documents/Python/geo/data/censo2010/enderecos_fins_estatisticos/TO.txt: 593312.
# Extração iniciada.
# Total de linhas gravadas em C:/Users/Luiz/Documents/Python/geo/data/censo2010/enderecos_fins_estatisticos/tratados/TO.csv: 58688.
#
# Fim das extrações.

# %% [markdown]
# #### 4. Verificação
#
# Conta a quantidade de CEPs distintos encontrados nas bases do Censo 2010.

# %%
qt_ceps_distintos = 0

for uf in ufs:
    arquivo_origem = "C:/Users/Luiz/Documents/Python/geo/data/censo2010/enderecos_fins_estatisticos/tratados/{0}.csv".format(uf)
    qt_ceps_distintos += len(pd.read_csv(arquivo_origem, sep='|')['cep'].unique())
    
print("Quantidade total de CEPs encontrados nas tabelas do Censo 2010: {0}".format(qt_ceps_distintos))
# Out:
# Quantidade total de CEPs encontrados nas tabelas do Censo 2010: 565325

# %% [markdown]
# ---
#
# ### Spatial Join - Ponto em polígono
#
# Realiza operações para assegurar que as linhas de logradouros pertencentes a um código regional (IBGE) interceptam o polígono desse código regional.

# %%
# Import de novas bibliotecas:
from shapely.geometry import Point
from shapely.geometry.polygon import Polygon
from shapely.geometry.multipolygon import MultiPolygon
from shapely.geometry.polygon import LinearRing
from shapely.geometry.linestring import LineString
import ast
import geopandas
from geopandas import GeoDataFrame

# %%
# Define funcao de correcao, necessaria devido ao tratamento feito no arquivo origem:
def corrige_ponto(shape):
    try:
        return Point(shape)
    except:
        try:
            return Point(shape[0])
        except:
            return Point(shape[0][0])

# %%
# Define funcao de correcao, necessaria devido ao tratamento feito no arquivo origem:
def corrige_linha(shape):
    try:
        return LineString(shape)
    except:
        try:
            return LineString(shape[0])
        except:
            return LineString(shape[0][0])

# %%
# Define funcao de correcao, necessaria devido ao tratamento feito no arquivo origem:
def corrige_poligono(shape):
    try:
        return Polygon(shape)
    except:
        try:
            return Polygon(shape[0])
        except:
            return Polygon(shape[0][0])

# %%
# Cria dataframe com os poligonos dos Codigos Regionais, por municipio:
arquivo_area = "data/shapefiles/tratados/areas_municipios.csv"
df_area = pd.read_csv(arquivo_area, delimiter="|", header=0, converters={"geometry.coordinates": ast.literal_eval})
df_area['coordenadas'] = df_area['geometry.coordinates']\
    .apply(lambda x: corrige_poligono(x))

# %%
df_area['coordenadas'].head()
# Out:
# 0    POLYGON Z ((-48.23248007099994 -15.78359663799...
# 1    POLYGON Z ((-48.86700312799996 -15.09734690599...
# 2    POLYGON Z ((-46.97635062799998 -14.93112359199...
# 3    POLYGON Z ((-49.90713464099997 -17.61460280199...
# 4    POLYGON Z ((-48.58274617899997 -16.94785546499...
# Name: coordenadas, dtype: object

# %%
# Cria geodataframe a partir do dataframe recem criado:
gdf_area = GeoDataFrame(
    df_area,
    geometry='coordenadas').drop('geometry.coordinates', axis=1)

# %%
gdf_area.head()
# Out:
#   properties.NOME  properties.CD_GEOCODI  properties.UF  \
# 0        BRASILIA                5300108             53
# 1   VILA PROPICIO                5222302             52
# 2        VILA BOA                5222203             52
# 3  VICENTINOPOLIS                5222054             52
# 4      VIANOPOLIS                5222005             52
#
#                                          coordenadas
# 0  POLYGON Z ((-48.23248 -15.78360 0.00000, -48.2...
# 1  POLYGON Z ((-48.86700 -15.09735 0.00000, -48.8...
# 2  POLYGON Z ((-46.97635 -14.93112 0.00000, -46.9...
# 3  POLYGON Z ((-49.90713 -17.61460 0.00000, -49.9...
# 4  POLYGON Z ((-48.58275 -16.94786 0.00000, -48.5...

# %%
# Realiza Spatial Join, gravando novos Shapefiles:
regioes = ['centro-oeste', 'nordeste', 'norte', 'sudeste', 'sul']
tipos_shape = ['roads', 'places', 'pois']
for regiao in regioes:
    gdf_area_regiao = gdf_area[gdf_area['properties.UF'].isin(list(df_ufs[df_ufs['regiao']==regiao]['codigo']))]
    for tipo_shape in tipos_shape:
        arquivo_origem = "data/shapefiles/tratados/{0}_{1}.csv"\
            .format(regiao, tipo_shape)
        arquivo_destino = "data/shapefiles/tratados/finais/{0}_{1}.shp"\
            .format(regiao, tipo_shape)
        print("\nImportando arquivo do tipo {0} da região '{1}'...".format(tipo_shape, regiao))
        df_regiao = pd.read_csv(arquivo_origem, delimiter="|", header=0, \
                                converters={"geometry.coordinates": ast.literal_eval})
        print("Iniciando tratamento...")
        try:
            df_regiao['coordenadas'] = df_regiao['geometry.coordinates']\
                .apply(lambda x: corrige_linha(x))
        except:
            df_regiao['coordenadas'] = df_regiao['geometry.coordinates']\
                .apply(lambda x: corrige_ponto(x))
        gdf_regiao = GeoDataFrame(
            df_regiao,
            geometry='coordenadas').drop('geometry.coordinates', axis=1)
        print("Realizando spatial join...")
        area_regiao = geopandas.sjoin(gdf_regiao, gdf_area_regiao, how="inner", op='intersects')
        print("Escrevendo arquivo {0}...".format(arquivo_destino))
        area_regiao.to_file(arquivo_destino)

print("\nFim das extrações.")
# Out:
# Importando arquivo do tipo roads da região 'centro-oeste'...
# Iniciando tratamento...
# Realizando spatial join...
# Escrevendo arquivo C:/Users/Luiz/Documents/Python/geo/data/shapefiles/tratados/finais/centro-oeste_roads.shp...
#
# Importando arquivo do tipo places da região 'centro-oeste'...
# Iniciando tratamento...
# Realizando spatial join...
# Escrevendo arquivo C:/Users/Luiz/Documents/Python/geo/data/shapefiles/tratados/finais/centro-oeste_places.shp...
#
# Importando arquivo do tipo pois da região 'centro-oeste'...
# Iniciando tratamento...
# Realizando spatial join...
# Escrevendo arquivo C:/Users/Luiz/Documents/Python/geo/data/shapefiles/tratados/finais/centro-oeste_pois.shp...
#
# Importando arquivo do tipo roads da região 'nordeste'...
# Iniciando tratamento...
# Realizando spatial join...
# Escrevendo arquivo C:/Users/Luiz/Documents/Python/geo/data/shapefiles/tratados/finais/nordeste_roads.shp...
#
# Importando arquivo do tipo places da região 'nordeste'...
# Iniciando tratamento...
# Realizando spatial join...
# Escrevendo arquivo C:/Users/Luiz/Documents/Python/geo/data/shapefiles/tratados/finais/nordeste_places.shp...
#
# Importando arquivo do tipo pois da região 'nordeste'...
# Iniciando tratamento...
# Realizando spatial join...
# Escrevendo arquivo C:/Users/Luiz/Documents/Python/geo/data/shapefiles/tratados/finais/nordeste_pois.shp...
#
# Importando arquivo do tipo roads da região 'norte'...
# Iniciando tratamento...
# Realizando spatial join...
# Escrevendo arquivo C:/Users/Luiz/Documents/Python/geo/data/shapefiles/tratados/finais/norte_roads.shp...
#
# Importando arquivo do tipo places da região 'norte'...
# Iniciando tratamento...
# Realizando spatial join...
# Escrevendo arquivo C:/Users/Luiz/Documents/Python/geo/data/shapefiles/tratados/finais/norte_places.shp...
#
# Importando arquivo do tipo pois da região 'norte'...
# Iniciando tratamento...
# Realizando spatial join...
# Escrevendo arquivo C:/Users/Luiz/Documents/Python/geo/data/shapefiles/tratados/finais/norte_pois.shp...
#
# Importando arquivo do tipo roads da região 'sudeste'...
# Iniciando tratamento...
# Realizando spatial join...
# Escrevendo arquivo C:/Users/Luiz/Documents/Python/geo/data/shapefiles/tratados/finais/sudeste_roads.shp...
#
# Importando arquivo do tipo places da região 'sudeste'...
# Iniciando tratamento...
# Realizando spatial join...
# Escrevendo arquivo C:/Users/Luiz/Documents/Python/geo/data/shapefiles/tratados/finais/sudeste_places.shp...
#
# Importando arquivo do tipo pois da região 'sudeste'...
# Iniciando tratamento...
# Realizando spatial join...
# Escrevendo arquivo C:/Users/Luiz/Documents/Python/geo/data/shapefiles/tratados/finais/sudeste_pois.shp...
#
# Importando arquivo do tipo roads da região 'sul'...
# Iniciando tratamento...
# Realizando spatial join...
# Escrevendo arquivo C:/Users/Luiz/Documents/Python/geo/data/shapefiles/tratados/finais/sul_roads.shp...
#
# Importando arquivo do tipo places da região 'sul'...
# Iniciando tratamento...
# Realizando spatial join...
# Escrevendo arquivo C:/Users/Luiz/Documents/Python/geo/data/shapefiles/tratados/finais/sul_places.shp...
#
# Importando arquivo do tipo pois da região 'sul'...
# Iniciando tratamento...
# Realizando spatial join...
# Escrevendo arquivo C:/Users/Luiz/Documents/Python/geo/data/shapefiles/tratados/finais/sul_pois.shp...
#
# Fim das extrações.

# %%
# Exemplo de resultado:
area_regiao.head()
# Out:
#         properties.name properties.fclass  properties.ref  \
# 0   SUPERMERCADO CONDOR       SUPERMARKET             NaN
# 1                  IBIS             HOTEL             NaN
# 2            MCDONALD'S         FAST_FOOD             NaN
# 3  RESTAURANTE BOA MESA        RESTAURANT             NaN
# 4   RESTAURANTE MILLONS        RESTAURANT             NaN
#
#                    coordenadas  index_right properties.NOME  \
# 0  POINT (-49.24488 -25.43421)         1564        CURITIBA
# 1  POINT (-49.27118 -25.42446)         1564        CURITIBA
# 2  POINT (-49.23518 -25.43599)         1564        CURITIBA
# 3  POINT (-49.23591 -25.43872)         1564        CURITIBA
# 4  POINT (-49.23577 -25.43891)         1564        CURITIBA
#
#    properties.CD_GEOCODI  properties.UF
# 0                4106902             41
# 1                4106902             41
# 2                4106902             41
# 3                4106902             41
# 4                4106902             41

# %% [markdown]
# ---
#
# ### Cruzamento dos novos Shapefiles com a base de endereços

# %%
# Import de biblioteca de regex:
import re

# %%
# Criacao de dicionario de numeros entre 0 e 100, para posterior aplicacao em regex:
lista_ate_cem = ['ZERO']
lista_1_9 = ['UM', 'DOIS', 'TRES', 'QUATRO', 'CINCO', 'SEIS', 'SETE', 'OITO', 'NOVE']
lista_10_19 = ['DEZ', 'ONZE', 'DOZE', 'TREZE', 'QUATORZE', 'QUINZE', 'DEZESSEIS', 'DEZESSETE', 'DEZOITO', 'DEZENOVE']
lista_dezenas = ['VINTE', 'TRINTA', 'QUARENTA', 'CINQUENTA', 'SESSENTA', 'SETENTA', 'OITENTA', 'NOVENTA', 'CEM']

lista_ate_cem += lista_1_9
lista_ate_cem += lista_10_19
dezena = 0
for n in range(20, 101):
    valor = ''
    if (n%10 == 0):
        dezena = int(n/10)-2
        valor = lista_dezenas[dezena]
    else:
        valor = lista_dezenas[dezena] + ' E ' + lista_1_9[(n%10)-1]
    lista_ate_cem.append(valor)

dict_ate_cem = {}
for i, n in enumerate(reversed(lista_ate_cem)):
    dict_ate_cem[n] = str(100-i)

dict_ate_cem['CATORZE'] = str(14)

dict_ate_cem['PRIMEIRA'] = str(1)
dict_ate_cem['SEGUNDA'] = str(2)
dict_ate_cem['TERCEIRA'] = str(3)
dict_ate_cem['QUARTA'] = str(4)
dict_ate_cem['QUINTA'] = str(5)
dict_ate_cem['SEXTA'] = str(6)
dict_ate_cem['SETIMA'] = str(7)
dict_ate_cem['OITAVA'] = str(8)
dict_ate_cem['NONA'] = str(9)
dict_ate_cem['DECIMA'] = str(10)
dict_ate_cem['VIGESIMA'] = str(20)

dict_ate_cem['PRIMEIRO'] = str(1)
dict_ate_cem['SEGUNDO'] = str(2)
dict_ate_cem['TERCEIRO'] = str(3)
dict_ate_cem['QUARTO'] = str(4)
dict_ate_cem['QUINTO'] = str(5)
dict_ate_cem['SEXTO'] = str(6)
dict_ate_cem['SETIMO'] = str(7)
dict_ate_cem['OITAVO'] = str(8)
dict_ate_cem['NONO'] = str(9)
dict_ate_cem['DECIMO'] = str(10)
dict_ate_cem['VIGESIMO'] = str(20)

rep = dict_ate_cem
rep = dict(('(^|\s)'+k+'($|\s)', ' ' + v + ' ') for k, v in rep.items())
pattern = re.compile("|".join(rep.keys()))

str(rep)
# Out:
# "{'(^|\\\\s)CEM($|\\\\s)': ' 100 ', '(^|\\\\s)NOVENTA E NOVE($|\\\\s)': ' 99 ', '(^|\\\\s)NOVENTA E OITO($|\\\\s)': ' 98 ', '(^|\\\\s)NOVENTA E SETE($|\\\\s)': ' 97 ', '(^|\\\\s)NOVENTA E SEIS($|\\\\s)': ' 96 ', '(^|\\\\s)NOVENTA E CINCO($|\\\\s)': ' 95 ', '(^|\\\\s)NOVENTA E QUATRO($|\\\\s)': ' 94 ', '(^|\\\\s)NOVENTA E TRES($|\\\\s)': ' 93 ', '(^|\\\\s)NOVENTA E DOIS($|\\\\s)': ' 92 ', '(^|\\\\s)NOVENTA E UM($|\\\\s)': ' 91 ', '(^|\\\\s)NOVENTA($|\\\\s)': ' 90 ', '(^|\\\\s)OITENTA E NOVE($|\\\\s)': ' 89 ', '(^|\\\\s)OITENTA E OITO($|\\\\s)': ' 88 ', '(^|\\\\s)OITENTA E SETE($|\\\\s)': ' 87 ', '(^|\\\\s)OITENTA E SEIS($|\\\\s)': ' 86 ', '(^|\\\\s)OITENTA E CINCO($|\\\\s)': ' 85 ', '(^|\\\\s)OITENTA E QUATRO($|\\\\s)': ' 84 ', '(^|\\\\s)OITENTA E TRES($|\\\\s)': ' 83 ', '(^|\\\\s)OITENTA E DOIS($|\\\\s)': ' 82 ', '(^|\\\\s)OITENTA E UM($|\\\\s)': ' 81 ', '(^|\\\\s)OITENTA($|\\\\s)': ' 80 ', '(^|\\\\s)SETENTA E NOVE($|\\\\s)': ' 79 ', '(^|\\\\s)SETENTA E OITO($|\\\\s)': ' 78 ', '(^|\\\\s)SETENTA E SETE($|\\\\s)': ' 77 ', '(^|\\\\s)SETENTA E SEIS($|\\\\s)': ' 76 ', '(^|\\\\s)SETENTA E CINCO($|\\
                     r'.*(?=(\s\w+){4})', r'.*(?=(\s\w+){3})', r'.*(?=(\s\w+){2})'
                    ]

# %%
# Definicao de funcao para aplicacao das expressoes regulares no geodataframe e no dataframe origens, 
#  seguida de join entre eles:
def aplica_regex_join(gdf, df, codigo_uf, variavel_origem, variavel_destino, regex, join='inner'):
    gdf[variavel_destino] = gdf[variavel_origem].apply(lambda x: re.sub('\s+', ' ', regex.sub(" ", str(x))).strip())
    
    df[variavel_destino] = df[variavel_origem].apply(lambda x: re.sub('\s+', ' ', regex.sub(" ", str(x))).strip())

    final_uf = gdf.merge(df, on=[variavel_destino, 'geocodigo'], how=join)
    return final_uf

# %%
# Percorre o geodataframe e o dataframe origens, gravando arquivo ao final:
def grava_arquivo_geo_CEP(arquivo_origem_gdf, arquivo_origem_df, destino, gravar=True, append=True):
    gdf = geopandas.read_file(arquivo_origem_gdf).drop_duplicates()
    gdf.columns = ['nome', 'tipo', 'nome_alternativo', 'index_right', 'municipio', 'geocodigo', 'codigo_uf', 'coordenadas']

    df = pd.read_csv(arquivo_origem_df, sep = '|').drop_duplicates()
    df.columns = ['geocodigo', 'nome', 'cep']
    df['geocodigo'] = df['geocodigo'].apply(lambda x: int(str(x)[0:7]))

    # Primeiros tratamentos:
    variavel_origem = 'nome'
    variavel_destino = 'nome2'
    gdf_origem = gdf.copy()
    gdf_origem[variavel_destino] = gdf_origem[variavel_origem]\
        .apply(lambda x: re.sub('\s+', ' ', re.sub("[\.\[\]\(\)\,\;\/]", " ", str(x))).strip())
    df_origem = df[df['cep'] >= 1000000].copy()
    df_origem['cep'] = df_origem['cep'].astype('int').astype('str')
    df_origem[variavel_destino] = df_origem[variavel_origem]\
        .apply(lambda x: re.sub('\s+', ' ', re.sub("[\.\[\]\(\)\,\;\/]", " ", str(x))).strip())
    aux_variavel_origem = variavel_origem

    # Substitui numeros:
    print('Tratando números...')
    gdf_origem[variavel_destino] = gdf_origem[variavel_destino]\
        .apply(lambda x: pattern.sub(lambda m: rep['(^|\s)'+(m.group(0)).strip()+'($|\s)'], str(x)))
    df_origem[variavel_destino] = df_origem[variavel_destino]\
        .apply(lambda x: pattern.sub(lambda m: rep['(^|\s)'+(m.group(0)).strip()+'($|\s)'], str(x)))

    # Mais tratamentos:
    #  - Tirar pontos dict_ate_cem['[\.\[\]\(\)\,\;\/]'] = ' '
    #  - Strip e tirar mais de um espaco seguido
    #  - Manter a coluna nome original
    #  - Trocar nomes de numeros por numeros
    #  - Um CEP encontrado não deve ser procurado novamente
    codigo_uf = int(str(df_origem['geocodigo'][0])[0:2])
    print('Código da UF: {0}.'.format(codigo_uf))
    array_ceps_restantes = df_origem['cep'].unique()
    n_ceps_origem = len(array_ceps_restantes)
    iniciado = False
    n_match_total = 0
    n_match_atual = 0
    n_match_anterior = 0
    palavras_excluidas = []
    variavel_origem = 'nome2'
    variavel_destino = 'nome3'
    colunas_df_origem = df_origem.columns
    df_origem['frequencia'] = df_origem.groupby(['nome', 'geocodigo', 'cep'])['cep'].transform('size')
    df_origem['maior_freq'] = df_origem.groupby(['cep'])['frequencia'].transform('max')
    aux_df_origem = df_origem[df_origem['frequencia']==df_origem['maior_freq']].drop_duplicates().copy()
    aux_df_origem.drop(['frequencia', 'maior_freq'], axis=1, inplace=True)
    aux_gdf_origem = gdf_origem[gdf_origem['codigo_uf']==codigo_uf].drop_duplicates().copy()
    progresso_palavras = 0
    progresso_cep = 0
    for p in palavras_exclusao:
        regex_excluir = re.compile(p)

        aux_df_final = aplica_regex_join(aux_gdf_origem, aux_df_origem,\
                                       codigo_uf, variavel_origem,\
                                       variavel_destino, regex_excluir)\
                            .drop_duplicates()

        aux_df_final['tratamento_final'] = p
        
        if (iniciado == False):
            df_final = aux_df_final.copy()
            iniciado = True
        else:
            df_final = df_final.append(aux_df_final, sort=False)

        n_match_atual = len(aux_df_final['cep'].unique())
        n_match_total = len(df_final['cep'].unique())
        if (n_match_atual > 0):
            n_match_anterior = n_match_atual
            palavras_excluidas.append(p + ': ' + str(n_match_atual))
            array_ceps_restantes = aux_df_origem[~aux_df_origem['cep'].isin(df_final['cep'].unique())]['cep'].unique()
            aux_df_origem = aux_df_origem[aux_df_origem['cep'].isin(array_ceps_restantes)]
        progresso_palavras = round(100*(palavras_exclusao.index(p))/len(palavras_exclusao), 2)
        progresso_cep = round(100*n_match_total/n_ceps_origem, 2)
        print('{0}% concluído ({1}) - Percentual de CEPs encontrados: {2}%              \r'\
              .format(progresso_palavras, p, progresso_cep), end="")
        variavel_origem = variavel_destino
    df_final.drop([i for i in list(df_final.columns) if '_y' in i], axis=1, inplace=True)
    df_final.drop(['index_right'], axis=1, inplace=True)
    df_final.columns = [re.sub('_x$', '', i) for i in list(df_final.columns)]
    df_final.drop_duplicates(inplace=True)
    df_final.groupby(['nome', 'geocodigo', 'cep'])['codigo_uf'].transform('size')
    df_final['frequencia'] = df_final.groupby(['nome', 'geocodigo', 'cep'])['codigo_uf'].transform('size')
    df_final['confianca_por_frequencia'] = round(df_final.groupby(['nome', 'geocodigo', 'cep'])['codigo_uf'].transform('size')\
                                  / df_final.groupby(['cep'])['frequencia'].transform('max'), 2)
    df_final['indice_verossimil'] = \
            df_final[variavel_destino].str.len()/df_final[aux_variavel_origem].str.len()
    progresso_palavras = round(100*(palavras_exclusao.index(p))/len(palavras_exclusao), 2)
    progresso_cep = round(100*max(n_match_atual, n_match_anterior)/n_ceps_origem, 2)
    print('Filtros aplicados, em ordem de mais influentes: {0}'\
          .format(', '.join(sorted(palavras_excluidas, reverse=True, key=lambda item: int(item.split(':')[1])))))
    print('\nPercentual de CEPs encontrados: {0}% ({1} de {2})'\
          .format(round(100*n_match_total/n_ceps_origem, 2),\
                 n_match_total, n_ceps_origem))
    if (gravar):
        if (append):
            df_final.to_csv(destino, mode='a+', header=False)
        else:
            df_final.to_csv(destino, mode='w+', header=True)
    else:
        return df_final

# %%
# Executa loop por ufs, tratando e exibindo percentual de CEPs idenficados em cada uma:
arquivo_destino = "data/resultados/geo_cep_202007.csv"
iniciado = False
gravar = True
ufs_gravacao = df_ufs
for index, uf in ufs_gravacao.iterrows():
    print("Carregando UF {0}...\r".format(uf['sigla']))
    arquivo_origem_gdf = "data/shapefiles/tratados/finais/{0}_roads.shp"\
        .format(uf['regiao'])
    arquivo_origem_df = "data/censo2010/enderecos_fins_estatisticos/tratados/{0}.csv"\
        .format(uf['sigla'])
    print("Tratando UF {0}...\r".format(uf['sigla']))
    if (gravar):
        grava_arquivo_geo_CEP(arquivo_origem_gdf, arquivo_origem_df, arquivo_destino, gravar, append=iniciado)
        print("UF {0} gravada no arquivo {1}.\n".format(uf['sigla'], arquivo_destino))
    else:
        aux_df_destino = grava_arquivo_geo_CEP(arquivo_origem_gdf, arquivo_origem_df, None, gravar, append=iniciado)
        if (iniciado):
            df_destino = df_destino.append(aux_df_destino, sort=False)
        else:
            df_destino = aux_df_destino.copy()
        print("UF {0} inserido no Dataframe {1}.\n".format(uf['sigla'], df_destino))
    iniciado = True
# Out:
# Carregando UF RO...
# Tratando UF RO...
# Tratando números...
# Código da UF: 11.
# Filtros aplicados, em ordem de mais influentes: ^RUA : 3742, ^AVENIDA : 592, ^TRAVESSA : 66, .*(?=(\s\w+){2}): 62, ^AV : 61, ^SAO : 59, ^PRESIDENTE : 29,  DE : 25, ^SANTA : 22, ^ALAMEDA : 19, ^DO : 19, ^DOUTOR : 18, ^GOVERNADOR : 15, ^BECO : 11, ^SANTO : 11,  DOS : 9, ^DAS : 9, .*(?=(\s\w+){3}): 9, ^DA : 8, ^DOS : 7,  DA : 6, ^CORONEL : 6, ^SENADOR : 6,  DO : 5, ^GENERAL : 4, ^R : 2, ^PROFESSOR : 2, ^DR : 1
#
# Percentual de CEPs encontrados: 86.75% (4825 de 5562)
# UF RO gravada no arquivo C:/Users/Luiz/Documents/Python/geo/data/resultados/geo_cep_202007.csv.
#
# Carregando UF AC...
# Tratando UF AC...
# Tratando números...
# Código da UF: 12.
# Filtros aplicados, em ordem de mais influentes: ^RUA : 468, ^TRAVESSA : 43, ^AVENIDA : 23, ^SAO : 19, ^ALAMEDA : 11, .*(?=(\s\w+){2}): 9, ^SANTA : 8, ^CORONEL : 5, ^DA : 3, ^BECO : 2, .*(?=(\s\w+){3}): 2,  DO : 1, ^DE : 1, ^DO : 1, ^SANTO : 1, ^DOUTOR : 1, ^SENADOR : 1
#
# Percentual de CEPs encontrados: 85.33% (599 de 702)
# UF AC gravada no arquivo C:/Users/Luiz/Documents/Python/geo/data/resultados/geo_cep_202007.csv.
#
# Carregando UF AM...
# Tratando UF AM...
# Tratando números...
# Código da UF: 13.
# Filtros aplicados, em ordem de mais influentes: ^RUA : 3444, ^SAO : 254, ^AVENIDA : 128, .*(?=(\s\w+){2}): 83, ^BECO : 78, ^TRAVESSA : 77, ^SANTA : 54,  ANTIGA .*: 35, ^DOUTOR : 32, ^DO : 27, ^SANTO : 24, ^DE : 23, ^CORONEL : 19, ^DAS : 16, ^DA : 15, ^PRESIDENTE : 12, ^DOS : 10, ^PROFESSOR : 8, .*(?=(\s\w+){3}): 8,  DE : 7, ^GENERAL : 7, ^S : 4, ^RODOVIA : 3,  DOS : 3, ^SENADOR : 3, ^ALAMEDA : 2, ^DOUTORA : 2, ^PROFESSORA : 2, .*(?=(\s\w+){4}): 2, ^AV : 1,  DO : 1, ^GOVERNADOR : 1, ^MINISTRO : 1
#
# Percentual de CEPs encontrados: 81.83% (4386 de 5360)
# UF AM gravada no arquivo C:/Users/Luiz/Documents/Python/geo/data/resultados/geo_cep_202007.csv.
#
# Carregando UF RR...
# Tratando UF RR...
# Tratando números...
# Código da UF: 14.
# Filtros aplicados, em ordem de mais influentes: ^RUA : 1026, ^AVENIDA : 156, .*(?=(\s\w+){2}): 51, ^TRAVESSA : 29, .*(?=(\s\w+){3}): 29, ^SAO : 15, ^DOUTOR : 8,  DE : 7, ^DO : 6, ^ALAMEDA : 5, ^SANTA : 4, ^PROFESSOR : 4, ^DA : 3, ^CORONEL : 3, ^PROFESSORA : 3, ^PRESIDENTE : 3, ^GENERAL : 3, ^R : 2, ^SANTO : 2, .*(?=(\s\w+){4}): 2, ^AV : 1, ^TRAV : 1, ^VIA : 1,  DO : 1, ^DOS : 1, ^DAS : 1, ^DR : 1, ^MINISTRO : 1
#
# Percentual de CEPs encontrados: 81.88% (1369 de 1672)
# UF RR gravada no arquivo C:/Users/Luiz/Documents/Python/geo/data/resultados/geo_cep_202007.csv.
#
# Carregando UF PA...
# Tratando UF PA...
# Tratando números...
# Código da UF: 15.
# Filtros aplicados, em ordem de mais influentes: ^RUA : 3461, ^TRAVESSA : 855, .*(?=(\s\w+){2}): 497, ^AVENIDA : 453, ^ALAMEDA : 358, ^SAO : 275, ^SANTA : 120, ^SANTO : 36, ^RODOVIA : 30, ^DOUTOR : 30, ^PRESIDENTE : 28, .*(?=(\s\w+){3}): 28, ^DA : 27, ^DO : 24, ^CORONEL : 20, ^DE : 17, ^DOS : 16, ^GOVERNADOR : 10, ^SENADOR : 10,  DE : 7, ^PROFESSOR : 7, ^BECO : 6,  DA : 6, ^DAS : 6, ^GENERAL : 4, ^R : 3, ^VIA : 3, ^S : 2, ^PROFESSORA : 2, .*(?=(\s\w+){4}): 2, ^AV : 1,  CONJUNTO .*: 1, ^DOUTORA : 1, ^MINISTRO : 1
#
# Percentual de CEPs encontrados: 75.36% (6347 de 8422)
# UF PA gravada no arquivo C:/Users/Luiz/Documents/Python/geo/data/resultados/geo_cep_202007.csv.
#
# Carregando UF AP...
# Tratando UF AP...
# Tratando números...
# Código da UF: 16.
# Filtros aplicados, em ordem de mais influentes: ^RUA : 481, ^AVENIDA : 378, .*(?=(\s\w+){2}): 54, ^TRAVESSA : 53, ^ALAMEDA : 28, ^DOS : 11, ^SAO : 11, .*(?=(\s\w+){3}): 10, ^DOUTOR : 9,  DE : 8, ^RODOVIA : 7, ^SANTA : 7, ^PROFESSOR : 6, ^PROFESSORA : 6, ^GENERAL : 6,  DA : 3,  CONJUNTO .*: 3, ^DA : 2, ^DAS : 2, ^SANTO : 2, ^PRESIDENTE : 2, ^VIA : 1,  DO : 1
#
# Percentual de CEPs encontrados: 80.22% (1091 de 1360)
# UF AP gravada no arquivo C:/Users/Luiz/Documents/Python/geo/data/resultados/geo_cep_202007.csv.
#
# Carregando UF TO...
# Tratando UF TO...
# Tratando números...
# Código da UF: 17.
# Filtros aplicados, em ordem de mais influentes: ^RUA : 1555, .*(?=(\s\w+){2}): 210, ^AVENIDA : 171, .*(?=(\s\w+){3}): 59, ^SAO : 27, ^SANTA : 14, ^R : 12, ^ALAMEDA : 10, ^TRAVESSA : 9, ^PRESIDENTE : 7, ^S : 5, ^SENADOR : 4,  DE : 3,  DO : 2, ^DOS : 2, ^DAS : 2, ^SANTO : 2, ^CORONEL : 2, ^MINISTRO : 2, .*(?=(\s\w+){4}): 2,  DA : 1, ^DE : 1, ^DA : 1, ^DOUTOR : 1, ^PROFESSORA : 1
#
# Percentual de CEPs encontrados: 54.56% (2105 de 3858)
# UF TO gravada no arquivo C:/Users/Luiz/Documents/Python/geo/data/resultados/geo_cep_202007.csv.
#
# Carregando UF MA...
# Tratando UF MA...
# Tratando números...
# Código da UF: 21.
# Filtros aplicados, em ordem de mais influentes: ^RUA : 1692, ^SAO : 125, ^AVENIDA : 105, ^TRAVESSA : 57, .*(?=(\s\w+){2}): 56, ^SANTA : 43, ^DO : 12, ^CORONEL : 10, ^DOS : 7, ^SANTO : 7, ^GENERAL : 7, ^DA : 6, ^PRESIDENTE : 6, .*(?=(\s\w+){3}): 6, ^BECO : 5, ^DAS : 5, ^PROFESSOR : 4,  DE : 3,  DA : 3, ^DE : 3, ^DOUTOR : 3, ^RODOVIA : 2, ^DOUTORA : 2, ^PROFESSORA : 2, ^SENADOR : 2, ^R : 1, ^PREFEITO : 1
#
# Percentual de CEPs encontrados: 78.46% (2175 de 2772)
# UF MA gravada no arquivo C:/Users/Luiz/Documents/Python/geo/data/resultados/geo_cep_202007.csv.
#
# Carregando UF PI...
# Tratando UF PI...
# Tratando números...
# Código da UF: 22.
# Filtros aplicados, em ordem de mais influentes: ^RUA : 2156, .*(?=(\s\w+){2}): 199, ^AVENIDA : 142, ^SAO : 66, ^PROFESSOR : 54, ^DOUTOR : 45, ^SANTA : 39, .*(?=(\s\w+){3}): 25,  DE : 18, ^CORONEL : 16, ^GOVERNADOR : 13, ^PRESIDENTE : 12, ^SANTO : 10,  CONJUNTO .*: 9, ^PROFESSORA : 9, ^SENADOR : 8, ^R : 6, ^DE : 4, ^DOUTORA : 4, ^GENERAL : 4, ^TRAVESSA : 3, ^BECO : 3,  DO : 3, ^DA : 3, ^ALAMEDA : 2, ^MINISTRO : 2, ^VIA : 1,  DOS : 1, ^DO : 1, ^DOS : 1
#
# Percentual de CEPs encontrados: 78.11% (2859 de 3660)
# UF PI gravada no arquivo C:/Users/Luiz/Documents/Python/geo/data/resultados/geo_cep_202007.csv.
#
# Carregando UF CE...
# Tratando UF CE...
# Tratando números...
# Código da UF: 23.
# Filtros aplicados, em ordem de mais influentes: ^RUA : 7013, ^AVENIDA : 383, ^TRAVESSA : 366, .*(?=(\s\w+){2}): 347, ^SAO : 128, ^DOUTOR : 126, ^CORONEL : 119, ^PROFESSOR : 89, ^SANTA : 63, .*(?=(\s\w+){3}): 59,  DE : 46, ^GENERAL : 36, ^DO : 35, ^ALAMEDA : 28, ^DA : 23, ^SENADOR : 22, ^DE : 21, ^MINISTRO : 16, ^SANTO : 13, ^PROFESSORA : 11, ^PRESIDENTE : 11, ^GOVERNADOR : 9,  DA : 7, ^DAS : 6, ^VIA : 5, ^DOS : 5, .*(?=(\s\w+){4}): 4, ^BECO : 3, ^DOUTORA : 3, ^RODOVIA : 2,  DOS : 2,  DAS : 2, ^TRAV : 1,  DO : 1
#
# Percentual de CEPs encontrados: 83.5% (9005 de 10784)
# UF CE gravada no arquivo C:/Users/Luiz/Documents/Python/geo/data/resultados/geo_cep_202007.csv.
#
# Carregando UF RN...
# Tratando UF RN...
# Tratando números...
# Código da UF: 24.
# Filtros aplicados, em ordem de mais influentes: ^RUA : 5331, .*(?=(\s\w+){2}): 401, ^AVENIDA : 316, ^SAO : 239, ^TRAVESSA : 206, ^DOUTOR : 137, ^SANTA : 116, .*(?=(\s\w+){3}): 97, ^CORONEL : 67, ^PRESIDENTE : 67, ^PROFESSOR : 64, ^SANTO : 38,  DE : 33, ^PROFESSORA : 25, ^SENADOR : 24, ^DA : 23, ^DO : 21, ^GOVERNADOR : 16,  DO : 15, ^DE : 14, ^GENERAL : 14,  DA : 13, ^ALAMEDA : 12, ^R : 9, .*(?=(\s\w+){4}): 8, ^PREFEITO : 7, ^MINISTRO : 5, ^DOS : 4, ^DAS : 4,  DOS : 3, ^BECO : 2, ^RODOVIA : 2,  DAS : 2
#
# Percentual de CEPs encontrados: 86.22% (7335 de 8507)
# UF RN gravada no arquivo C:/Users/Luiz/Documents/Python/geo/data/resultados/geo_cep_202007.csv.
#
# Carregando UF PB...
# Tratando UF PB...
# Tratando números...
# Código da UF: 25.
# Filtros aplicados, em ordem de mais influentes: ^RUA : 4872, .*(?=(\s\w+){2}): 598, ^AVENIDA : 287, .*(?=(\s\w+){3}): 256,  DE : 138, ^DOUTOR : 131, ^SAO : 91, ^PROFESSOR : 79, ^PROFESSORA : 73,  DA : 62, ^TRAVESSA : 55, ^SANTA : 54, ^CORONEL : 54, ^PRESIDENTE : 38, .*(?=(\s\w+){4}): 36, ^PREFEITO : 28, ^SANTO : 16, ^GENERAL : 14, ^SENADOR : 13, ^GOVERNADOR : 12,  DO : 9, ^MINISTRO : 7, ^DA : 5, ^DAS : 5, ^DO : 4, ^DOS : 3, ^BECO : 2, ^ALAMEDA : 2, ^DOUTORA : 2, ^R : 1, ^RODOVIA : 1,  DOS : 1,  DAS : 1, ^DE : 1
#
# Percentual de CEPs encontrados: 84.29% (6951 de 8247)
# UF PB gravada no arquivo C:/Users/Luiz/Documents/Python/geo/data/resultados/geo_cep_202007.csv.
#
# Carregando UF PE...
# Tratando UF PE...
# Tratando números...
# Código da UF: 26.
# Filtros aplicados, em ordem de mais influentes: ^RUA : 13330, .*(?=(\s\w+){2}): 1418, ^AVENIDA : 677, ^SAO : 347, ^DOUTOR : 324, .*(?=(\s\w+){3}): 321, ^TRAVESSA : 176, ^SANTA : 162, ^PROFESSOR : 160, ^DA : 122, ^DO : 105, ^CORONEL : 98,  DE : 81,  ANTIGA .*: 61, ^GENERAL : 60, ^DE : 59, ^SANTO : 58, ^PRESIDENTE : 56, ^PROFESSORA : 40, .*(?=(\s\w+){4}): 28,  DA : 27, ^SENADOR : 27,  DO : 25, ^ALAMEDA : 22, ^GOVERNADOR : 21, ^DOS : 12, ^MINISTRO : 12, ^PREFEITO : 8, ^R : 7, ^BECO : 6,  DOS : 6, ^DAS : 6, ^RODOVIA : 5, ^AV : 4,  DAS : 4, ^DOUTORA : 4, ^VIA : 2, ^TRAV : 1,  LOTE .*: 1, ^CEL : 1, ^PROF : 1
#
# Percentual de CEPs encontrados: 78.24% (17885 de 22858)
# UF PE gravada no arquivo C:/Users/Luiz/Documents/Python/geo/data/resultados/geo_cep_202007.csv.
#
# Carregando UF AL...
# Tratando UF AL...
# Tratando números...
# Código da UF: 27.
# Filtros aplicados, em ordem de mais influentes: ^RUA : 2631, .*(?=(\s\w+){2}): 309, ^AVENIDA : 154, ^SAO : 140, ^SANTA : 104, .*(?=(\s\w+){3}): 98, ^TRAVESSA : 96, ^DOUTOR : 93, ^PROFESSOR : 56, ^CORONEL : 32, ^SANTO : 31,  DE : 29, ^GOVERNADOR : 23, ^ALAMEDA : 21, ^DO : 17, ^PROFESSORA : 15, ^SENADOR : 11, ^PREFEITO : 10, ^PRESIDENTE : 10,  DA : 9, .*(?=(\s\w+){4}): 8, ^DOUTORA : 7, ^BECO : 6, ^DA : 5, ^GENERAL : 5, ^DE : 4, ^MINISTRO : 3,  DOS : 2, ^DAS : 2,  DO : 1, ^DOS : 1,  CONJ .*: 1
#
# Percentual de CEPs encontrados: 83.49% (3934 de 4712)
# UF AL gravada no arquivo C:/Users/Luiz/Documents/Python/geo/data/resultados/geo_cep_202007.csv.
#
# Carregando UF SE...
# Tratando UF SE...
# Tratando números...
# Código da UF: 28.
# Filtros aplicados, em ordem de mais influentes: ^RUA : 1189, ^AVENIDA : 125, .*(?=(\s\w+){2}): 120, ^TRAVESSA : 61, ^SAO : 43, .*(?=(\s\w+){3}): 32, ^DOUTOR : 30,  DE : 18, ^GENERAL : 18, ^SANTA : 17, ^CORONEL : 13, ^PROFESSOR : 13, ^SANTO : 6, ^PROFESSORA : 6,  DO : 5, ^DE : 5, ^ALAMEDA : 3,  DA : 3, ^DAS : 3, ^PREFEITO : 3, ^BECO : 2, ^RODOVIA : 2,  DOS : 2, ^DO : 2, ^DA : 2, ^DOS : 2,  ANTIGA .*: 1, ^GOVERNADOR : 1, ^SENADOR : 1, ^PRESIDENTE : 1, .*(?=(\s\w+){4}): 1
#
# Percentual de CEPs encontrados: 83.25% (1730 de 2078)
# UF SE gravada no arquivo C:/Users/Luiz/Documents/Python/geo/data/resultados/geo_cep_202007.csv.
#
# Carregando UF BA...
# Tratando UF BA...
# Tratando números...
# Código da UF: 29.
# Filtros aplicados, em ordem de mais influentes: ^RUA : 11322, .*(?=(\s\w+){2}): 1404, ^AVENIDA : 887, ^TRAVESSA : 732, ^SAO : 536, .*(?=(\s\w+){3}): 255, ^SANTA : 209, ^SANTO : 125, ^ALAMEDA : 117, ^DA : 116, ^PROFESSOR : 116, ^DOUTOR : 109, ^DO : 105,  DE : 57, ^VIA : 53, ^DE : 41, ^PRESIDENTE : 38, ^CORONEL : 33, ^GENERAL : 31, ^PROFESSORA : 22, ^DAS : 21,  DA : 20, ^BECO : 18,  DO : 17, ^DOS : 15, .*(?=(\s\w+){4}): 15, ^R : 14,  DOS : 13, ^SENADOR : 12, ^MINISTRO : 8, ^GOVERNADOR : 6,  CONJ .*: 4, ^RODOVIA : 3, ^DOUTORA : 3, ^S : 2, ^AV : 1, ^TRAV : 1,  DAS : 1,  CONJUNTO .*: 1, ^DR : 1, ^PROFA : 1, ^PREFEITO : 1
#
# Percentual de CEPs encontrados: 75.4% (16486 de 21865)
# UF BA gravada no arquivo C:/Users/Luiz/Documents/Python/geo/data/resultados/geo_cep_202007.csv.
#
# Carregando UF MG...
# Tratando UF MG...
# Tratando números...
# Código da UF: 31.
# Filtros aplicados, em ordem de mais influentes: ^RUA : 36592, ^AVENIDA : 2308, .*(?=(\s\w+){2}): 2107, ^SAO : 730, ^DOUTOR : 645,  DE : 420, .*(?=(\s\w+){3}): 419, ^SANTA : 366, ^ALAMEDA : 323, ^PROFESSOR : 299, ^CORONEL : 284, ^BECO : 265, ^TRAVESSA : 239,  DA : 163, ^R : 157, ^DO : 150, ^SANTO : 140, ^PROFESSORA : 130, ^PRESIDENTE : 80, ^DOS : 78, ^DAS : 77,  ANTIGA .*: 72, ^DA : 69, ^DE : 61, ^GENERAL : 48, ^PREFEITO : 46,  DO : 40, ^SENADOR : 39,  DOS : 37, ^GOVERNADOR : 34, ^RODOVIA : 16, .*(?=(\s\w+){4}): 16, ^MINISTRO : 12, ^AV : 11, ^DR : 9, ^VIA : 8, ^DOUTORA : 8,  DAS : 5, ^PROF : 4, ^CEL : 3, ^PROFA : 1
#
# Percentual de CEPs encontrados: 85.33% (46511 de 54510)
# UF MG gravada no arquivo C:/Users/Luiz/Documents/Python/geo/data/resultados/geo_cep_202007.csv.
#
# Carregando UF ES...
# Tratando UF ES...
# Tratando números...
# Código da UF: 32.
# Filtros aplicados, em ordem de mais influentes: ^RUA : 7964, ^AVENIDA : 608, .*(?=(\s\w+){2}): 456, ^SAO : 169, ^BECO : 108, ^SANTA : 106, .*(?=(\s\w+){3}): 103, ^TRAVESSA : 72, ^RODOVIA : 60, ^PRESIDENTE : 56, ^DOUTOR : 53,  DE : 52, ^PROFESSOR : 37, ^DO : 35, ^DOS : 34, ^PROFESSORA : 32, ^GOVERNADOR : 30, ^CORONEL : 26, ^DAS : 25, ^SANTO : 22,  DA : 18, ^DA : 16, ^ALAMEDA : 13, ^PREFEITO : 11,  DOS : 9,  DO : 8, ^GENERAL : 8, .*(?=(\s\w+){4}): 8, ^SENADOR : 5, ^DE : 3,  DAS : 1,  ANTIGA .*: 1, ^DR : 1, ^DOUTORA : 1, ^PROF : 1
#
# Percentual de CEPs encontrados: 66.33% (10152 de 15305)
# UF ES gravada no arquivo C:/Users/Luiz/Documents/Python/geo/data/resultados/geo_cep_202007.csv.
#
# Carregando UF RJ...
# Tratando UF RJ...
# Tratando números...
# Código da UF: 33.
# Filtros aplicados, em ordem de mais influentes: ^RUA : 18312, .*(?=(\s\w+){2}): 1123, ^AVENIDA : 838, ^TRAVESSA : 680, ^DOUTOR : 400, ^SAO : 355, .*(?=(\s\w+){3}): 319,  DE : 142, ^SANTA : 133, ^CORONEL : 118, ^GENERAL : 110, ^PROFESSOR : 96, ^ALAMEDA : 93, ^PRESIDENTE : 92, ^SANTO : 71, ^DA : 54, ^DO : 53, ^DE : 51,  DA : 48, ^R : 39, ^PREFEITO : 39, ^RODOVIA : 37, ^PROFESSORA : 36, .*(?=(\s\w+){4}): 30, ^DOS : 29, ^DAS : 28, ^SENADOR : 26, ^GOVERNADOR : 24, ^BECO : 19,  DOS : 17,  DO : 14, ^MINISTRO : 14,  ANTIGA .*: 6, ^VIA : 4, ^CEL : 3, ^DR : 3, ^TRAV : 1,  DAS : 1, ^S : 1, ^DOUTORA : 1, ^GEN : 1
#
# Percentual de CEPs encontrados: 48.47% (23461 de 48402)
# UF RJ gravada no arquivo C:/Users/Luiz/Documents/Python/geo/data/resultados/geo_cep_202007.csv.
#
# Carregando UF SP...
# Tratando UF SP...
# Tratando números...
# Código da UF: 35.
# Filtros aplicados, em ordem de mais influentes: ^RUA : 110931, ^AVENIDA : 8383, .*(?=(\s\w+){2}): 8006, ^DOUTOR : 3302, ^TRAVESSA : 3014, .*(?=(\s\w+){3}): 2248, ^SAO : 1736, ^PROFESSOR : 1413, ^ALAMEDA : 1372,  DE : 1049, ^SANTA : 865, ^CORONEL : 599, ^SANTO : 413, ^PROFESSORA : 408, ^GENERAL : 359, ^PRESIDENTE : 358,  DA : 338, .*(?=(\s\w+){4}): 298, ^DOS : 242, ^DO : 224, ^DE : 223, ^DAS : 185, ^DA : 184, ^R : 182, ^SENADOR : 181, ^RODOVIA : 147, ^DR : 135,  DO : 129, ^PREFEITO : 120, ^VIA : 112, ^MINISTRO : 112,  DOS : 88, ^GOVERNADOR : 67,  ANTIGA .*: 55, ^PROF : 50, ^DOUTORA : 33, ^AV : 26, ^PROFA : 19,  DAS : 18, ^BECO : 10, ^AL : 9, ^CEL : 8, ^S : 1, ^STO : 1, ^DRA : 1, ^GEN : 1
#
# Percentual de CEPs encontrados: 81.53% (147655 de 181109)
# UF SP gravada no arquivo C:/Users/Luiz/Documents/Python/geo/data/resultados/geo_cep_202007.csv.
#
# Carregando UF PR...
# Tratando UF PR...
# Tratando números...
# Código da UF: 41.
# Filtros aplicados, em ordem de mais influentes: ^RUA : 25748, .*(?=(\s\w+){2}): 1573, ^AVENIDA : 1160, ^TRAVESSA : 828, .*(?=(\s\w+){3}): 558, ^SAO : 419, ^DOUTOR : 382, ^SANTA : 245, ^PROFESSOR : 220, ^PRESIDENTE : 130, ^CORONEL : 125,  DE : 116, ^PROFESSORA : 100, ^ALAMEDA : 95, ^SANTO : 93, ^GENERAL : 87, ^RODOVIA : 57, ^PREFEITO : 54, ^DO : 51, ^SENADOR : 47,  DA : 44, .*(?=(\s\w+){4}): 44, ^GOVERNADOR : 31, ^DE : 23, ^DA : 22,  DO : 21,  DOS : 17, ^DOS : 16, ^DAS : 16, ^DOUTORA : 13, ^MINISTRO : 12, ^BECO : 11, ^R : 3, ^VIA : 1,  DAS : 1,  ANTIGA .*: 1
#
# Percentual de CEPs encontrados: 85.51% (32364 de 37847)
# UF PR gravada no arquivo C:/Users/Luiz/Documents/Python/geo/data/resultados/geo_cep_202007.csv.
#
# Carregando UF SC...
# Tratando UF SC...
# Tratando números...
# Código da UF: 42.
# Filtros aplicados, em ordem de mais influentes: ^RUA : 14155, .*(?=(\s\w+){2}): 803, ^AVENIDA : 370, .*(?=(\s\w+){3}): 239, ^TRAVESSA : 221, ^SAO : 193, ^SANTA : 112, ^DOUTOR : 100,  DE : 78, ^PRESIDENTE : 70, ^PROFESSOR : 61, ^CORONEL : 53, ^RODOVIA : 48, ^SANTO : 35, ^PROFESSORA : 32,  DA : 27, ^GENERAL : 26, ^PREFEITO : 25, ^GOVERNADOR : 19, .*(?=(\s\w+){4}): 14, ^ALAMEDA : 13,  DOS : 12, ^MINISTRO : 12, ^DA : 10, ^DOS : 9, ^DAS : 9, ^SENADOR : 9,  DO : 8, ^DE : 8, ^DO : 7, ^BECO : 5, ^R : 1,  ANTIGA .*: 1
#
# Percentual de CEPs encontrados: 69.8% (16785 de 24046)
# UF SC gravada no arquivo C:/Users/Luiz/Documents/Python/geo/data/resultados/geo_cep_202007.csv.
#
# Carregando UF RS...
# Tratando UF RS...
# Tratando números...
# Código da UF: 43.
# Filtros aplicados, em ordem de mais influentes: ^RUA : 16895, ^AVENIDA : 1075, .*(?=(\s\w+){2}): 1017, ^TRAVESSA : 643, ^DOUTOR : 431, ^SAO : 337, .*(?=(\s\w+){3}): 244, ^GENERAL : 205, ^CORONEL : 166, ^SANTA : 151, ^PROFESSOR : 139, ^BECO : 94, ^SANTO : 84, ^PRESIDENTE : 81,  DE : 71, ^DO : 62, ^DA : 59, ^SENADOR : 57, ^DE : 54, ^DAS : 36,  DA : 34, ^DOS : 29, ^PROFESSORA : 28, ^ALAMEDA : 26, .*(?=(\s\w+){4}): 18, ^PREFEITO : 15, ^PROF : 11, ^GOVERNADOR : 10,  DOS : 9, ^DOUTORA : 9,  DO : 8, ^RODOVIA : 5, ^DR : 5, ^R : 3, ^MINISTRO : 3,  DAS : 2, ^GEN : 2, ^TRAV : 1, ^VIA : 1,  ANTIGA .*: 1,  CONJUNTO .*: 1, ^CEL : 1, ^DRA : 1
#
# Percentual de CEPs encontrados: 81.06% (22124 de 27295)
# UF RS gravada no arquivo C:/Users/Luiz/Documents/Python/geo/data/resultados/geo_cep_202007.csv.
#
# Carregando UF MS...
# Tratando UF MS...
# Tratando números...
# Código da UF: 50.
# Filtros aplicados, em ordem de mais influentes: ^RUA : 5751, ^TRAVESSA : 359, ^AVENIDA : 335, .*(?=(\s\w+){2}): 226, ^SAO : 80, ^ALAMEDA : 75, ^DOUTOR : 69, ^SANTA : 49,  DE : 42, .*(?=(\s\w+){3}): 42, ^PRESIDENTE : 41, ^GENERAL : 39, ^CORONEL : 36, ^SANTO : 20, ^DO : 19, ^DA : 15, ^PROFESSOR : 15, ^SENADOR : 13,  DA : 12, ^DE : 11,  DO : 7, ^DOS : 7, ^PROFESSORA : 6, ^MINISTRO : 6, ^DAS : 3, ^R : 2, ^RODOVIA : 1,  DOS : 1, ^STA : 1, ^DR : 1, ^DOUTORA : 1, ^PREFEITO : 1, .*(?=(\s\w+){4}): 1
#
# Percentual de CEPs encontrados: 87.23% (7287 de 8354)
# UF MS gravada no arquivo C:/Users/Luiz/Documents/Python/geo/data/resultados/geo_cep_202007.csv.
#
# Carregando UF MT...
# Tratando UF MT...
# Tratando números...
# Código da UF: 51.
# Filtros aplicados, em ordem de mais influentes: ^RUA : 3764, ^AVENIDA : 519, .*(?=(\s\w+){2}): 135, ^TRAVESSA : 45, ^SAO : 41, ^R : 35, ^PRESIDENTE : 34, .*(?=(\s\w+){3}): 25, ^CORONEL : 21,  DE : 18, ^SANTA : 16, ^GOVERNADOR : 15, ^PROFESSORA : 14, ^GENERAL : 12, ^DO : 11, ^DOUTOR : 11, ^PROFESSOR : 11, ^SANTO : 9, ^SENADOR : 9, ^DA : 8, ^DAS : 8, ^ALAMEDA : 7, ^DE : 6, ^RODOVIA : 5, ^MINISTRO : 5,  DA : 3, ^AV : 2, ^DOS : 2, ^BECO : 1,  DO : 1, .*(?=(\s\w+){4}): 1
#
# Percentual de CEPs encontrados: 85.24% (4794 de 5624)
# UF MT gravada no arquivo C:/Users/Luiz/Documents/Python/geo/data/resultados/geo_cep_202007.csv.
#
# Carregando UF GO...
# Tratando UF GO...
# Tratando números...
# Código da UF: 52.
# Filtros aplicados, em ordem de mais influentes: ^RUA : 14798, ^AVENIDA : 1266, .*(?=(\s\w+){2}): 442, ^SAO : 184, ^ALAMEDA : 135, ^SANTA : 126, ^DOUTOR : 92, .*(?=(\s\w+){3}): 91, ^PRESIDENTE : 65,  DE : 56, ^PROFESSOR : 54, ^TRAVESSA : 52, ^VIA : 37, ^DO : 32, ^CORONEL : 30, ^DOS : 29, ^GENERAL : 24, ^DE : 23, ^SENADOR : 23, ^SANTO : 21,  DA : 18, ^S : 18, ^DAS : 16, ^DA : 15, ^PROFESSORA : 12, .*(?=(\s\w+){4}): 10, ^R : 9,  ANTIGA .*: 6,  DO : 4, ^GOVERNADOR : 4,  DOS : 2, ^MINISTRO : 2, ^PREFEITO : 2, ^RODOVIA : 1, ^DR : 1, ^DOUTORA : 1, ^DRA : 1, ^PROF : 1
#
# Percentual de CEPs encontrados: 76.16% (17703 de 23245)
# UF GO gravada no arquivo C:/Users/Luiz/Documents/Python/geo/data/resultados/geo_cep_202007.csv.
#
# Carregando UF DF...
# Tratando UF DF...
# Tratando números...
# Código da UF: 53.
# Filtros aplicados, em ordem de mais influentes: .*(?=(\s\w+){2}): 6228,  CONJ .*: 365, .*(?=(\s\w+){3}): 225, ^RUA : 224,  CONJUNTO .*: 166,  LOTE .*: 109, .*(?=(\s\w+){4}): 14, ^AVENIDA : 4, ^AV : 2, ^DA : 2, ^SAO : 2,  DE : 1, ^SANTO : 1
#
# Percentual de CEPs encontrados: 34.7% (7343 de 21162)
# UF DF gravada no arquivo C:/Users/Luiz/Documents/Python/geo/data/resultados/geo_cep_202007.csv.

# %% [markdown]
# ---
#
# ### Busca por locais próximos e CEP relacionado ao respectivo centroide

# %%
# Import de novas bibliotecas:
from shapely import wkt
from shapely.geometry import MultiPoint
from shapely.ops import nearest_points
import geopy.distance as dist
from scipy.spatial import distance
import numpy as np

# %%
# Define funcao que retorna ponto proximo a poligono:
def get_proximo(ponto, pts=pts3):
    return nearest_points(ponto, pts)[1]

# %%
# Define funcao que retorna distancia entre dois pontos:
def distancia_dois_pontos(p1, p2):
    return dist.distance((p1.y, p1.x), (p2.y, p2.x)).km

# %%
# Define funcao que retorna centroide a partir de tres pontos:
def centroide_tres_pontos(p1, p2, p3):
    pontos = MultiPoint([(p1.x, p1.y), (p2.x, p2.y), (p3.x, p3.y)])
    return pontos.centroid

# %%
# Define funcao que retorna o CEP mais proximo ao ponto informado:
def retorna_CEP(ponto, df_geocep, lista_geocodigos):
    gdf_geocep = GeoDataFrame(
        df_geocep[df_geocep['geocodigo'].isin(lista_geocodigos)],
        geometry='coordenadas')
    pts3 = gdf_geocep.geometry.unary_union
    return geopandas.sjoin(GeoDataFrame([get_proximo(ponto, pts3)], \
                                        columns=['geometry']), \
                           gdf_geocep, how="inner", op='intersects')

# %%
arquivo_geocep = "C:/Users/Luiz/Documents/Python/geo/data/resultados/geo_cep_202007.csv"
df_geocep = pd.read_csv(arquivo_geocep, delimiter=",", header=0)
df_geocep['coordenadas'] = df_geocep['coordenadas'].apply(wkt.loads)

# %%
# Define funcao que procura por locais proximos segundo a distancia maxima e filtro informados.
#  Devido a didatica aplicada, o filtro aqui era um divisor do numero de CEP, que era aplicado para se
#  observar se o resto da divisao do CEP por esse divisor era zero:
def procura_locais(gdf_locais, df_geocep, tipo_1, tipo_2, tipo_3, distancia_maxima_1, distancia_maxima_2, divisor):
    tamanho = len(gdf_locais[gdf_locais['tipo']==tipo_1])
    n = 0
    for i1, r1 in gdf_locais[gdf_locais['tipo']==tipo_1].iterrows():
        print("Progresso: {0}%          \r".format(round(100*n/tamanho)), end="")
        n += 1
        for i2, r2 in gdf_locais[gdf_locais['tipo']==tipo_2].iterrows():
            distancia_1 = distancia_dois_pontos(r1['coordenadas'], r2['coordenadas'])
            if (distancia_1 < distancia_maxima_1):
                for i3, r3 in gdf_locais[gdf_locais['tipo']==tipo_3].iterrows():
                    distancia_2 = distancia_dois_pontos(r2['coordenadas'], r3['coordenadas'])
                    if (distancia_2 < distancia_maxima_2):
                        print("{0} ({1}, {2}) está a {3} km de " \
                              "{4} ({5}, {6}), que está a {7} km de " \
                              "{8} ({9}, {10})."\
                              .format(r1['nome'], r1['coordenadas'].y, r1['coordenadas'].x,\
                                      str(round(distancia_1, 2)),\
                                      r2['nome'], r2['coordenadas'].y, r2['coordenadas'].x,\
                                      str(round(distancia_2, 2)),\
                                      r3['nome'], r3['coordenadas'].y, r3['coordenadas'].x\
                                     ))
                        aux_geocodigos = [r1['geocodigo'], r2['geocodigo'], r3['geocodigo']]
                        geocodigos = list(set(aux_geocodigos))
                        centroide = centroide_tres_pontos(r1['coordenadas'], r2['coordenadas'], r3['coordenadas'])
                        print("O centroide entre esses três pontos é ({0}, {1})"\
                             .format(centroide.y, centroide.x))
                        try:
                            cep = retorna_CEP(centroide, df_geocep, geocodigos)['cep'][0]
                            print("O CEP mais próximo do centroide é {0}, cujo resto da divisão por {1} é {2}"\
                                  .format(cep, divisor, cep%divisor))
                        except:
                            print("Nenhum CEP encontrado para o(s) geocódigos {0}"\
                              .format(geocodigos))
                        print("\n----------------------------------------------------\n")

# %%
# Exemplo de busca por locais onde um fast food esta a ate 100 metros de um hotel, 
#  o qual esta a ate 200 metros de uma livraria/banca:

tipo_1 = 'FAST_FOOD'
tipo_2 = 'HOTEL'
tipo_3 = 'BOOKSHOP'

distancia_maxima_1 = 0.1
distancia_maxima_2 = 0.2
divisor = 4

regioes = ['centro-oeste', 'nordeste', 'norte', 'sudeste', 'sul']

for r in regioes:
    print("\nPesquisando na região '{0}'...\n".format(r))
    arquivo_locais = "data/shapefiles/tratados/finais/{0}_pois.shp"\
        .format(r)
    gdf_locais = geopandas.read_file(arquivo_locais)
    gdf_locais.drop(['index_righ'], axis=1, inplace=True)
    gdf_locais.columns = ['nome', 'tipo', 'nome_alternativo', 'municipio', 'geocodigo', 'codigo_uf', 'coordenadas']
    procuraLocais(gdf_locais, df_geocep, tipo_1, tipo_2, tipo_3, distancia_maxima_1, distancia_maxima_2, divisor)
    
print("\nFim das pesquisas")
# Out:
# Pesquisando na região 'centro-oeste'...
#
# LANCHES CENTRAL (-22.5398509, -55.7261391) está a 0.07 km de HOTEL DE TRANSITO E OFICIAIS (-22.5393163, -55.7264685), que está a 0.14 km de PROFETICA (-22.5382873, -55.7273028).
# O centroide entre esses três pontos é (-22.539151500000003, -55.726636799999994)
# Nenhum CEP encontrado para o(s) geocódigos [5006606]
#
# ----------------------------------------------------
#
# FILHO DA FRUTA (-22.5390744, -55.7266452) está a 0.03 km de HOTEL DE TRANSITO E OFICIAIS (-22.5393163, -55.7264685), que está a 0.14 km de PROFETICA (-22.5382873, -55.7273028).
# O centroide entre esses três pontos é (-22.53889266666667, -55.726805500000005)
# Nenhum CEP encontrado para o(s) geocódigos [5006606]
#
# ----------------------------------------------------
#
# SUBWAY (-22.5396069, -55.726312) está a 0.04 km de HOTEL DE TRANSITO E OFICIAIS (-22.5393163, -55.7264685), que está a 0.14 km de PROFETICA (-22.5382873, -55.7273028).
# O centroide entre esses três pontos é (-22.539070166666665, -55.726694433333336)
# Nenhum CEP encontrado para o(s) geocódigos [5006606]
#
# ----------------------------------------------------
#
# Progresso: 100%
# Pesquisando na região 'nordeste'...
#
# LA BIRBA (-13.0030067, -38.5321754) está a 0.06 km de HIT HOTEL (-13.0034903, -38.5325011), que está a 0.11 km de PORTO DOS LIVROS (-13.0025189, -38.5322547).
# O centroide entre esses três pontos é (-13.0030053, -38.5323104)
# Nenhum CEP encontrado para o(s) geocódigos [2927408]
#
# ----------------------------------------------------
#
# LA BIRBA (-13.0030067, -38.5321754) está a 0.04 km de VILLAGE NOVO (-13.003203, -38.5325203), que está a 0.08 km de PORTO DOS LIVROS (-13.0025189, -38.5322547).
# O centroide entre esses três pontos é (-13.002909533333332, -38.5323168)
# Nenhum CEP encontrado para o(s) geocódigos [2927408]
#
# ----------------------------------------------------
#
# LA BIRBA (-13.0030067, -38.5321754) está a 0.09 km de GRANDE HOTEL DA BARRA (-13.0022065, -38.5324115), que está a 0.04 km de PORTO DOS LIVROS (-13.0025189, -38.5322547).
# O centroide entre esses três pontos é (-13.002577366666666, -38.532280533333335)
# Nenhum CEP encontrado para o(s) geocódigos [2927408]
#
# ----------------------------------------------------
#
# LA BIRBA (-13.0030067, -38.5321754) está a 0.06 km de SOL BARRA (-13.0026867, -38.5317263), que está a 0.06 km de PORTO DOS LIVROS (-13.0025189, -38.5322547).
# O centroide entre esses três pontos é (-13.002737433333332, -38.53205213333334)
# Nenhum CEP encontrado para o(s) geocódigos [2927408]
#
# ----------------------------------------------------
#
# ALO PAOZINHO (-13.003337, -38.5321581) está a 0.09 km de PRAIA PORTA DA BARRA (-13.0038885, -38.5327549), que está a 0.16 km de PORTO DOS LIVROS (-13.0025189, -38.5322547).
# O centroide entre esses três pontos é (-13.003248133333335, -38.53238923333333)
# Nenhum CEP encontrado para o(s) geocódigos [2927408]
#
# ----------------------------------------------------
#
# ALO PAOZINHO (-13.003337, -38.5321581) está a 0.04 km de HIT HOTEL (-13.0034903, -38.5325011), que está a 0.11 km de PORTO DOS LIVROS (-13.0025189, -38.5322547).
# O centroide entre esses três pontos é (-13.003115399999999, -38.53230463333333)
# Nenhum CEP encontrado para o(s) geocódigos [2927408]
#
# ----------------------------------------------------
#
# ALO PAOZINHO (-13.003337, -38.5321581) está a 0.04 km de VILLAGE NOVO (-13.003203, -38.5325203), que está a 0.08 km de PORTO DOS LIVROS (-13.0025189, -38.5322547).
# O centroide entre esses três pontos é (-13.003019633333333, -38.532311033333336)
# Nenhum CEP encontrado para o(s) geocódigos [2927408]
#
# ----------------------------------------------------
#
# ALO PAOZINHO (-13.003337, -38.5321581) está a 0.09 km de SOL BARRA (-13.0026867, -38.5317263), que está a 0.06 km de PORTO DOS LIVROS (-13.0025189, -38.5322547).
# O centroide entre esses três pontos é (-13.002847533333332, -38.53204636666667)
# Nenhum CEP encontrado para o(s) geocódigos [2927408]
#
# ----------------------------------------------------
#
# PIZZA MARINI (-13.0056198, -38.5255695) está a 0.04 km de THE HOTEL (-13.0059329, -38.5258007), que está a 0.19 km de SARAIVA MEGASTORE (-13.0068504, -38.5243134).
# O centroide entre esses três pontos é (-13.006134366666666, -38.52522786666667)
# Nenhum CEP encontrado para o(s) geocódigos [2927408]
#
# ----------------------------------------------------
#
# PIZZA MARINI (-13.0056198, -38.5255695) está a 0.04 km de THE HOTEL (-13.0059329, -38.5258007), que está a 0.2 km de CARAMURE PUBLICACOES (-13.0072991, -38.524658).
# O centroide entre esses três pontos é (-13.006283933333334, -38.52534273333334)
# Nenhum CEP encontrado para o(s) geocódigos [2927408]
#
# ----------------------------------------------------
#
# BOALI (-13.006707, -38.5253955) está a 0.1 km de THE HOTEL (-13.0059329, -38.5258007), que está a 0.19 km de SARAIVA MEGASTORE (-13.0068504, -38.5243134).
# O centroide entre esses três pontos é (-13.006496766666666, -38.525169866666666)
# Nenhum CEP encontrado para o(s) geocódigos [2927408]
#
# ----------------------------------------------------
#
# BOALI (-13.006707, -38.5253955) está a 0.1 km de THE HOTEL (-13.0059329, -38.5258007), que está a 0.2 km de CARAMURE PUBLICACOES (-13.0072991, -38.524658).
# O centroide entre esses três pontos é (-13.006646333333334, -38.52528473333333)
# Nenhum CEP encontrado para o(s) geocódigos [2927408]
#
# ----------------------------------------------------
#
# MARIA PRETA (-12.9764506, -38.5139463) está a 0.04 km de POUSADA DA PRACA (-12.9767519, -38.5137922), que está a 0.06 km de LDM LIVRARIA MULTICAMPI (-12.9771441, -38.5142022).
# O centroide entre esses três pontos é (-12.9767822, -38.513980233333335)
# Nenhum CEP encontrado para o(s) geocódigos [2927408]
#
# ----------------------------------------------------
#
# MARIA PRETA (-12.9764506, -38.5139463) está a 0.05 km de HOTEL DON JUAN (-12.9767556, -38.5136458), que está a 0.07 km de LDM LIVRARIA MULTICAMPI (-12.9771441, -38.5142022).
# O centroide entre esses três pontos é (-12.976783433333333, -38.51393143333333)
# Nenhum CEP encontrado para o(s) geocódigos [2927408]
#
# ----------------------------------------------------
#
# MARIA PRETA (-12.9764506, -38.5139463) está a 0.1 km de HOTEL COLONIAL CHILE (-12.9756961, -38.5134945), que está a 0.2 km de LIVRARIA ANCHIETA (-12.9752727, -38.5117049).
# O centroide entre esses três pontos é (-12.975806466666667, -38.51304856666666)
# Nenhum CEP encontrado para o(s) geocódigos [2927408]
#
# ----------------------------------------------------
#
# MARIA PRETA (-12.9764506, -38.5139463) está a 0.1 km de HOTEL COLONIAL CHILE (-12.9756961, -38.5134945), que está a 0.18 km de LDM LIVRARIA MULTICAMPI (-12.9771441, -38.5142022).
# O centroide entre esses três pontos é (-12.976430266666668, -38.513881)
# Nenhum CEP encontrado para o(s) geocódigos [2927408]
#
# ----------------------------------------------------
#
# LANCHONETE REAL (-12.9754184, -38.5132649) está a 0.04 km de HOTEL COLONIAL CHILE (-12.9756961, -38.5134945), que está a 0.2 km de LIVRARIA ANCHIETA (-12.9752727, -38.5117049).
# O centroide entre esses três pontos é (-12.9754624, -38.512821433333336)
# Nenhum CEP encontrado para o(s) geocódigos [2927408]
#
# ----------------------------------------------------
#
# LANCHONETE REAL (-12.9754184, -38.5132649) está a 0.04 km de HOTEL COLONIAL CHILE (-12.9756961, -38.5134945), que está a 0.18 km de LDM LIVRARIA MULTICAMPI (-12.9771441, -38.5142022).
# O centroide entre esses três pontos é (-12.976086200000003, -38.513653866666665)
# Nenhum CEP encontrado para o(s) geocódigos [2927408]
#
# ----------------------------------------------------
#
# ACARAJE DA MARY (-12.9736888, -38.5110877) está a 0.06 km de ARTHEMIS HOTEL (-12.9739776, -38.511574), que está a 0.14 km de LIVRARIA ANCHIETA (-12.9752727, -38.5117049).
# O centroide entre esses três pontos é (-12.974313033333333, -38.51145553333333)
# Nenhum CEP encontrado para o(s) geocódigos [2927408]
#
# ----------------------------------------------------
#
# ACARAJE DA MARY (-12.9736888, -38.5110877) está a 0.01 km de BAHIACAFE HOTEL (-12.9737077, -38.5109873), que está a 0.19 km de LIVRARIA ANCHIETA (-12.9752727, -38.5117049).
# O centroide entre esses três pontos é (-12.974223066666667, -38.511259966666664)
# Nenhum CEP encontrado para o(s) geocódigos [2927408]
#
# ----------------------------------------------------
# LANCHONETE DO CEARA (-15.2454549, -40.2481106) está a 0.04 km de HOTEL DEL REY (-15.2455082, -40.2477811), que está a 0.16 km de REI DOS REIS (-15.2454055, -40.2463339).
# O centroide entre esses três pontos é (-15.245456200000001, -40.24740853333333)
# Nenhum CEP encontrado para o(s) geocódigos [2916401]
#
# ----------------------------------------------------
#
# LANCHONETE DO CEARA (-15.2454549, -40.2481106) está a 0.09 km de ITAHOTEL (-15.2455611, -40.2472405), que está a 0.1 km de REI DOS REIS (-15.2454055, -40.2463339).
# O centroide entre esses três pontos é (-15.245473833333335, -40.24722833333333)
# Nenhum CEP encontrado para o(s) geocódigos [2916401]
#
# ----------------------------------------------------
#
# LANCHONETE DO CEARA (-15.2454549, -40.2481106) está a 0.09 km de ITAHOTEL (-15.2455611, -40.2472405), que está a 0.18 km de CANTINHO DO CRISTAO (-15.2453589, -40.2455391).
# O centroide entre esses três pontos é (-15.245458300000001, -40.2469634)
# O CEP mais próximo do centroide é 45705000, cujo resto da divisão por 4 é 0
#
# ----------------------------------------------------
#
# CALDO DE CANA E LANCHONETE CENTRAL (-7.0249605, -37.2773446) está a 0.1 km de MILINDRA 4 (-7.024919, -37.2764784), que está a 0.11 km de DISTRIBUIDORA NOBREGA (-7.0254777, -37.2772542).
# O centroide entre esses três pontos é (-7.025119066666666, -37.27702573333333)
# Nenhum CEP encontrado para o(s) geocódigos [2510808]
#
# ----------------------------------------------------
#
# SUBWAY (-7.024592, -37.277151) está a 0.08 km de MILINDRA 4 (-7.024919, -37.2764784), que está a 0.11 km de DISTRIBUIDORA NOBREGA (-7.0254777, -37.2772542).
# O centroide entre esses três pontos é (-7.024996233333333, -37.2769612)
# Nenhum CEP encontrado para o(s) geocódigos [2510808]
#
# ----------------------------------------------------
#
# ZECA'S LANCHES (-7.028545, -37.2760694) está a 0.08 km de MELQUIADES HOTEL (-7.0291381, -37.2764808), que está a 0.09 km de BANCA CATEDRAL (-7.029644, -37.2758216).
# O centroide entre esses três pontos é (-7.0291090333333335, -37.27612393333333)
# Nenhum CEP encontrado para o(s) geocódigos [2510808]
#
# ----------------------------------------------------
#
# ZECA'S LANCHES (-7.028545, -37.2760694) está a 0.08 km de PATOS PALACE HOTEL (-7.02902, -37.2755253), que está a 0.08 km de BANCA CATEDRAL (-7.029644, -37.2758216).
# O centroide entre esses três pontos é (-7.029069666666667, -37.27580543333333)
# Nenhum CEP encontrado para o(s) geocódigos [2510808]
#
# ----------------------------------------------------
#
# MENINA ARRETADA (-7.8368661, -38.103652) está a 0.1 km de POUSADA OPCAO (-7.8367698, -38.1027833), que está a 0.12 km de ESQUINA DA CULTURA (-7.8378036, -38.1025989).
# O centroide entre esses três pontos é (-7.8371465, -38.10301139999999)
# Nenhum CEP encontrado para o(s) geocódigos [2615706]
#
# ----------------------------------------------------
#
# LANCHONETE GUANABARA (-7.8369228, -38.1036709) está a 0.1 km de POUSADA OPCAO (-7.8367698, -38.1027833), que está a 0.12 km de ESQUINA DA CULTURA (-7.8378036, -38.1025989).
# O centroide entre esses três pontos é (-7.8371654, -38.1030177)
# Nenhum CEP encontrado para o(s) geocódigos [2615706]
#
# ----------------------------------------------------
#
# TAPIOKINHA DA FAFA (-8.9811199, -38.2189211) está a 0.06 km de SHEIK HOTEL (-8.9815943, -38.2185849), que está a 0.04 km de LIVRARIA (-8.9819858, -38.2186405).
# O centroide entre esses três pontos é (-8.981566666666668, -38.2187155)
# O CEP mais próximo do centroide é 56460000, cujo resto da divisão por 4 é 0
#
# ----------------------------------------------------
#
# X-BURGUER DO PAINHA (-8.9810613, -38.2188764) está a 0.07 km de SHEIK HOTEL (-8.9815943, -38.2185849), que está a 0.04 km de LIVRARIA (-8.9819858, -38.2186405).
# O centroide entre esses três pontos é (-8.981547133333333, -38.2187006)
# O CEP mais próximo do centroide é 56460000, cujo resto da divisão por 4 é 0
#
# ----------------------------------------------------
#
# FIA HAMBURGUES (-8.9812873, -38.2187901) está a 0.04 km de SHEIK HOTEL (-8.9815943, -38.2185849), que está a 0.04 km de LIVRARIA (-8.9819858, -38.2186405).
# O centroide entre esses três pontos é (-8.981622466666666, -38.21867183333333)
# O CEP mais próximo do centroide é 56460000, cujo resto da divisão por 4 é 0
#
# ----------------------------------------------------
#
# FIA HAMBURGUES (-8.9812873, -38.2187901) está a 0.08 km de DUQUE POUSADA (-8.9817489, -38.2181964), que está a 0.06 km de LIVRARIA (-8.9819858, -38.2186405).
# O centroide entre esses três pontos é (-8.981674, -38.218542333333325)
# O CEP mais próximo do centroide é 56460000, cujo resto da divisão por 4 é 0
#
# ----------------------------------------------------
#
# ACAILANDIA (-8.9810915, -38.218899) está a 0.07 km de SHEIK HOTEL (-8.9815943, -38.2185849), que está a 0.04 km de LIVRARIA (-8.9819858, -38.2186405).
# O centroide entre esses três pontos é (-8.9815572, -38.21870813333334)
# O CEP mais próximo do centroide é 56460000, cujo resto da divisão por 4 é 0
#
# ----------------------------------------------------
#
# LANCHONETE KI SABOR (-14.2267201, -42.7801978) está a 0.09 km de HOTEL LEOPOLDO (-14.226499, -42.7810204), que está a 0.12 km de LIVRARIA MAE DO SALVADOR (-14.2275458, -42.7806708).
# O centroide entre esses três pontos é (-14.226921633333333, -42.78062966666667)
# O CEP mais próximo do centroide é 43430000, cujo resto da divisão por 4 é 0
#
# ----------------------------------------------------
#
# LANCHONETE KI SABOR (-14.2267201, -42.7801978) está a 0.09 km de HOTEL LEOPOLDO (-14.226499, -42.7810204), que está a 0.09 km de PRIMICIAS LIVRARIA EVANGELICA (-14.226531, -42.7801522).
# O centroide entre esses três pontos é (-14.226583366666667, -42.7804568)
# O CEP mais próximo do centroide é 43430000, cujo resto da divisão por 4 é 0
#
# ----------------------------------------------------
#
# Progresso: 100%
# Pesquisando na região 'norte'...
#
# MICHELLI LANCHONETE BAR (3.8468225, -51.8361255) está a 0.08 km de HOTEL FLORESTA (3.8475442, -51.8358889), que está a 0.04 km de BANCA DO DIARIO (3.8476855, -51.8362125).
# O centroide entre esses três pontos é (3.8473507333333337, -51.83607563333334)
# O CEP mais próximo do centroide é 6898000, cujo resto da divisão por 4 é 0
#
# ----------------------------------------------------
#
# Progresso: 100%
# Pesquisando na região 'sudeste'...
#
# REI DO PASTEL (-19.9388607, -43.9386669) está a 0.07 km de HOTEL BOULEVARD (-19.9393502, -43.9381793), que está a 0.12 km de LIVRARIA LEITURA (-19.9391445, -43.9370442).
# O centroide entre esses três pontos é (-19.939118466666667, -43.937963466666666)
# Nenhum CEP encontrado para o(s) geocódigos [3106200]
#
# ----------------------------------------------------
#
# REI DO PASTEL (-19.9388607, -43.9386669) está a 0.07 km de HOTEL BOULEVARD (-19.9393502, -43.9381793), que está a 0.18 km de QUIXOTE LIVRARIA E CAFE (-19.939122, -43.9364426).
# O centroide entre esses três pontos é (-19.939110966666664, -43.93776293333334)
# Nenhum CEP encontrado para o(s) geocódigos [3106200]
#
# ----------------------------------------------------
#
# REI DO PASTEL (-19.9388607, -43.9386669) está a 0.07 km de HOTEL BOULEVARD (-19.9393502, -43.9381793), que está a 0.17 km de ESQUERDA LITERARIA (-19.937897, -43.9376651).
# O centroide entre esses três pontos é (-19.93870263333333, -43.93817043333333)
# Nenhum CEP encontrado para o(s) geocódigos [3106200]
#
# ----------------------------------------------------
#
# TMAK TEMAKERIA (-19.9390029, -43.9387581) está a 0.07 km de HOTEL BOULEVARD (-19.9393502, -43.9381793), que está a 0.12 km de LIVRARIA LEITURA (-19.9391445, -43.9370442).
# O centroide entre esses três pontos é (-19.939165866666666, -43.937993866666666)
# Nenhum CEP encontrado para o(s) geocódigos [3106200]
#
# ----------------------------------------------------
#
# TMAK TEMAKERIA (-19.9390029, -43.9387581) está a 0.07 km de HOTEL BOULEVARD (-19.9393502, -43.9381793), que está a 0.18 km de QUIXOTE LIVRARIA E CAFE (-19.939122, -43.9364426).
# O centroide entre esses três pontos é (-19.939158366666664, -43.93779333333333)
# Nenhum CEP encontrado para o(s) geocódigos [3106200]
#
# ----------------------------------------------------
#
# TMAK TEMAKERIA (-19.9390029, -43.9387581) está a 0.07 km de HOTEL BOULEVARD (-19.9393502, -43.9381793), que está a 0.17 km de ESQUERDA LITERARIA (-19.937897, -43.9376651).
# O centroide entre esses três pontos é (-19.93875003333333, -43.93820083333333)
# Nenhum CEP encontrado para o(s) geocódigos [3106200]
#
# ----------------------------------------------------
#
# MULINO PIZZERIA (-19.9390606, -43.9386621) está a 0.06 km de HOTEL BOULEVARD (-19.9393502, -43.9381793), que está a 0.12 km de LIVRARIA LEITURA (-19.9391445, -43.9370442).
# O centroide entre esses três pontos é (-19.9391851, -43.93796186666666)
# Nenhum CEP encontrado para o(s) geocódigos [3106200]
#
# ----------------------------------------------------
#
# MULINO PIZZERIA (-19.9390606, -43.9386621) está a 0.06 km de HOTEL BOULEVARD (-19.9393502, -43.9381793), que está a 0.18 km de QUIXOTE LIVRARIA E CAFE (-19.939122, -43.9364426).
# O centroide entre esses três pontos é (-19.939177599999997, -43.937761333333334)
# Nenhum CEP encontrado para o(s) geocódigos [3106200]
#
# ----------------------------------------------------
#
# MULINO PIZZERIA (-19.9390606, -43.9386621) está a 0.06 km de HOTEL BOULEVARD (-19.9393502, -43.9381793), que está a 0.17 km de ESQUERDA LITERARIA (-19.937897, -43.9376651).
# O centroide entre esses três pontos é (-19.938769266666664, -43.93816883333333)
# Nenhum CEP encontrado para o(s) geocódigos [3106200]
#
# ----------------------------------------------------
#
# DOMINO'S (-23.5662154, -46.6525925) está a 0.04 km de TRANSAMERICA PRIME INTERNATIONAL PLAZA (-23.5665061, -46.6527942), que está a 0.16 km de FNAC (-23.5659703, -46.6513863).
# O centroide entre esses três pontos é (-23.5662306, -46.652257666666664)
# Nenhum CEP encontrado para o(s) geocódigos [3550308]
#
# ----------------------------------------------------
#
# DOMINO'S (-23.5662154, -46.6525925) está a 0.04 km de TRANSAMERICA PRIME INTERNATIONAL PLAZA (-23.5665061, -46.6527942), que está a 0.07 km de FNAC (-23.5664922, -46.6520917).
# O centroide entre esses três pontos é (-23.566404566666666, -46.652492800000005)
# Nenhum CEP encontrado para o(s) geocódigos [3550308]
#
# ----------------------------------------------------
#
# IBOTIRAMA (-23.554896, -46.6568895) está a 0.02 km de BELLA AUGUSTA PALACE HOTEL (-23.5550898, -46.6568728), que está a 0.11 km de BANCA FREI CANECA (-23.5558882, -46.6562715).
# O centroide entre esses três pontos é (-23.555291333333333, -46.656677933333334)
# Nenhum CEP encontrado para o(s) geocódigos [3550308]
#
# ----------------------------------------------------
#
# IBOTIRAMA (-23.554896, -46.6568895) está a 0.03 km de SAVOY PALACE HOTEL (-23.5550743, -46.6571151), que está a 0.12 km de BANCA FREI CANECA (-23.5558882, -46.6562715).
# O centroide entre esses três pontos é (-23.555286166666665, -46.656758700000005)
# Nenhum CEP encontrado para o(s) geocódigos [3550308]
#
# ----------------------------------------------------
#
# RAGAZZO (-23.5588263, -46.6615019) está a 0.04 km de RENAISSANCE SAO PAULO HOTEL (-23.5585539, -46.6618166), que está a 0.2 km de LIVRARIA CULTURA (-23.5591532, -46.6599876).
# O centroide entre esses três pontos é (-23.558844466666667, -46.66110203333333)
# Nenhum CEP encontrado para o(s) geocódigos [3550308]
#
# ----------------------------------------------------
#
# MCDONALD'S (-23.5589154, -46.6611721) está a 0.08 km de RENAISSANCE SAO PAULO HOTEL (-23.5585539, -46.6618166), que está a 0.2 km de LIVRARIA CULTURA (-23.5591532, -46.6599876).
# O centroide entre esses três pontos é (-23.558874166666666, -46.660992099999994)
# Nenhum CEP encontrado para o(s) geocódigos [3550308]
#
# ----------------------------------------------------
#
# SUBWAY (-23.5658364, -46.6534012) está a 0.1 km de TRANSAMERICA PRIME INTERNATIONAL PLAZA (-23.5665061, -46.6527942), que está a 0.16 km de FNAC (-23.5659703, -46.6513863).
# O centroide entre esses três pontos é (-23.566104266666667, -46.65252723333333)
# Nenhum CEP encontrado para o(s) geocódigos [3550308]
#
# ----------------------------------------------------
#
# SUBWAY (-23.5658364, -46.6534012) está a 0.1 km de TRANSAMERICA PRIME INTERNATIONAL PLAZA (-23.5665061, -46.6527942), que está a 0.07 km de FNAC (-23.5664922, -46.6520917).
# O centroide entre esses três pontos é (-23.566278233333332, -46.65276236666667)
# Nenhum CEP encontrado para o(s) geocódigos [3550308]
#
# ----------------------------------------------------
#
# SUBWAY (-23.5658364, -46.6534012) está a 0.05 km de NOBILE PAULISTA PRIME (-23.566233, -46.653605), que está a 0.16 km de FNAC (-23.5664922, -46.6520917).
# O centroide entre esses três pontos é (-23.5661872, -46.65303263333333)
# Nenhum CEP encontrado para o(s) geocódigos [3550308]
#
# ----------------------------------------------------
#
# SUKIYA TOKIO BOWLS & NOODLES (-23.5719851, -46.6450268) está a 0.01 km de HOTEL PARAISO (-23.5719605, -46.6449643), que está a 0.1 km de GIOSTRI LIVRARIA (-23.5710403, -46.6450916).
# O centroide entre esses três pontos é (-23.571661966666664, -46.64502756666667)
# Nenhum CEP encontrado para o(s) geocódigos [3550308]
#
# ----------------------------------------------------
#
# SUBWAY (-23.5550841, -46.6359748) está a 0.08 km de AKASAKA (-23.5552747, -46.6352124), que está a 0.09 km de LIVRARIA FONOMAG (-23.5553653, -46.6343354).
# O centroide entre esses três pontos é (-23.555241366666667, -46.635174199999994)

# %% [markdown]
# Acredito ser necessário ajustar o tratamento dos geocódigos (Códigos Regionais/de Setores do IBGE), visto que foi recorrente a ausência de CEP em geocódigos. Além disso, a execução de três loops não é performática, certamente existindo opções melhores para substituí-los.
#
# De qualquer forma, para o objetivo da apresentação esse tipo de correção não foi essencial e alcançou-se uma base de 425 mil CEPs distintos, com seus dados e polígonos correspondentes, além de 211 mil pontos de interesse.
